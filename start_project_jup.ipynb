# %%
import time
import numpy as np
import pandas as pd
import requests 
from bs4 import BeautifulSoup

# %%
#import sklaern

v_indexes = [ 0 ]
eleven_columns = ['version' , 'year' , 'engine' , 'current_mileage' , 'hand' , 'gearBox' , 'color' , 'original_onership' , 'next_test_in' , 'annual_licensing_fee' , 'price']
ten_columns = ['version' , 'year' , 'engine' , 'current_mileage' , 'hand' , 'gearBox' , 'color' , 'original_onership' ,'next_test_in',  'annual_licensing_fee' ]
cars = pd.read_csv(r"C:\Users\avoav\Introduction to Data Science\Project סמסטר א\project-semester-a\DataFrame_cars_urls\cars_urls_data.csv" ,index_col=0 )

cars = cars.rename( columns = {'0' : 'url'} )
df_Det = pd.DataFrame( columns= eleven_columns)
for url in cars['url']:
    
    one_car = requests.get(url)
    soup = BeautifulSoup(one_car.content , 'html.parser')
    
    try:
        str_price = soup.find('div' , xs= "auto")
        str_price = str_price.get_text()
        price = ""
        for char in str_price:
            if (char.isdigit()):
                price = price + char
    except:
        print ("An exception occurred")
        continue
    
    Det = soup.select('td' , class_='MuiTableCell-root MuiTableCell-body MuiTableCell-alignLeft MuiTableCell-paddingNone')
        
    det_array = []
# how to choose only the second td each time?
    for i in range(len(Det)):
        if (i%2 != 0):
            det_array.append(Det[i].get_text())
            if (Det[i].get_text() == None):
                det_array.append(None)
    det_array.append(int(price)) 
    
    if (len(det_array) ==11):
        df_det_array = pd.DataFrame(np.array([det_array]) , columns = eleven_columns  ) 
    
    #how to append data with different number of columns 
    df_Det = pd.concat([df_Det ,df_det_array] , ignore_index = True , sort = False).fillna(0)
    print(df_Det)
    

print(df_Det)
# Out:
# An exception occurred
#             version  year           engine current_mileage hand  gearBox  \
# 0  פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2  אוטומטי
#
#   color original_onership next_test_in annual_licensing_fee  price
# 0  אפור            ליסינג     ‏1,424 ₪                21999      0
# An exception occurred
# An exception occurred
#                 version  year           engine current_mileage hand  gearBox  \
# 0      פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2  אוטומטי
# 1  ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2  אוטומטי
#
#   color original_onership next_test_in annual_licensing_fee  price
# 0  אפור            ליסינג     ‏1,424 ₪                21999      0
# 1  אפור             פרטית     2 חודשים             ‏1,424 ₪  59900
#                  version  year           engine current_mileage hand  gearBox  \
# 0       פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2  אוטומטי
# 1   ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2  אוטומטי
# 2  סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1  אוטומטי
#
#         color original_onership next_test_in annual_licensing_fee  price
# 0        אפור            ליסינג     ‏1,424 ₪                21999      0
# 1        אפור             פרטית     2 חודשים             ‏1,424 ₪  59900
# 2  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪  74900
#                  version  year           engine current_mileage hand  gearBox  \
# 0       פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2  אוטומטי
# 1   ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2  אוטומטי
# 2  סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1  אוטומטי
# 3  סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1  אוטומטי
#
#         color original_onership next_test_in annual_licensing_fee  price
# 0        אפור            ליסינג     ‏1,424 ₪                21999      0
# 1        אפור             פרטית     2 חודשים             ‏1,424 ₪  59900
# 2  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪  74900
# 3  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪  74900
# An exception occurred
# An exception occurred
#                        version  year           engine current_mileage hand  \
# 0             פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1         ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4  מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
#
#    gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0  אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1  אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4  אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
#
#     price
# 0       0
# 1   59900
# 2   74900
# 3   74900
# 4  135000
# An exception occurred
# An exception occurred
# An exception occurred
#                        version  year           engine current_mileage hand  \
# 0             פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1         ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4  מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5         טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
#
#    gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0  אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1  אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4  אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5  אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
#
#     price
# 0       0
# 1   59900
# 2   74900
# 3   74900
# 4  135000
# 5   11999
# An exception occurred
#                        version  year           engine current_mileage hand  \
# 0             פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1         ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4  מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5         טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6    ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
#
#    gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0  אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1  אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4  אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5  אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
# 6  אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
#
#     price
# 0       0
# 1   59900
# 2   74900
# 3   74900
# 4  135000
# 5   11999
# 6   97000
#                        version  year           engine current_mileage hand  \
# 0             פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1         ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4  מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5         טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6    ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7    ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
#
#    gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0  אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1  אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4  אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5  אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
# 6  אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 7  אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
#
#     price
# 0       0
# 1   59900
# 2   74900
# 3   74900
# 4  135000
# 5   11999
# 6   97000
# 7   97000
#                        version  year           engine current_mileage hand  \
# 0             פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1         ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4  מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5         טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6    ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7    ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8    ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
#
#    gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0  אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1  אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4  אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5  אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
# 6  אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 7  אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 8  אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
#
#     price
# 0       0
# 1   59900
# 2   74900
# 3   74900
# 4  135000
# 5   11999
# 6   97000
# 7   97000
# 8   97000
#                        version  year           engine current_mileage hand  \
# 0             פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1         ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3        סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4  מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5         טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6    ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7    ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8    ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9  מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
#
#    gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0  אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1  אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3  אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4  אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5  אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
# 6  אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 7  אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 8  אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 9  אוטומטי        שחור             פרטית     4 חודשים             ‏1,962 ₪
#
#     price
# 0       0
# 1   59900
# 2   74900
# 3   74900
# 4  135000
# 5   11999
# 6   97000
# 7   97000
# 8   97000
# 9  140000
# An exception occurred
# An exception occurred
# An exception occurred
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
#
#     gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0   אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1   אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4   אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5   אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
# 6   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 7   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 8   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 9   אוטומטי        שחור             פרטית     4 חודשים             ‏1,962 ₪
# 10  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
#
#      price
# 0        0
# 1    59900
# 2    74900
# 3    74900
# 4   135000
# 5    11999
# 6    97000
# 7    97000
# 8    97000
# 9   140000
# 10   17500
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
#
#     gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0   אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1   אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4   אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5   אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
# 6   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 7   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 8   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 9   אוטומטי        שחור             פרטית     4 חודשים             ‏1,962 ₪
# 10  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
# 11  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
#
#      price
# 0        0
# 1    59900
# 2    74900
# 3    74900
# 4   135000
# 5    11999
# 6    97000
# 7    97000
# 8    97000
# 9   140000
# 10   17500
# 11   17500
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
#
#     gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0   אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1   אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4   אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5   אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
# 6   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 7   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 8   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 9   אוטומטי        שחור             פרטית     4 חודשים             ‏1,962 ₪
# 10  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
# 11  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
# 12  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
#
#      price
# 0        0
# 1    59900
# 2    74900
# 3    74900
# 4   135000
# 5    11999
# 6    97000
# 7    97000
# 8    97000
# 9   140000
# 10   17500
# 11   17500
# 12   17500
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 13         מאזדה CX-5 EXECUTIVE  2013  1998 ליטר בנזין         149,000    3
#
#     gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0   אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1   אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4   אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5   אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
# 6   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 7   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 8   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 9   אוטומטי        שחור             פרטית     4 חודשים             ‏1,962 ₪
# 10  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
# 11  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
# 12  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
# 13  אוטומטי        אפור            ליסינג     3 חודשים             ‏1,693 ₪
#
#      price
# 0        0
# 1    59900
# 2    74900
# 3    74900
# 4   135000
# 5    11999
# 6    97000
# 7    97000
# 8    97000
# 9   140000
# 10   17500
# 11   17500
# 12   17500
# 13   69900
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 13         מאזדה CX-5 EXECUTIVE  2013  1998 ליטר בנזין         149,000    3
# 14  אלפא רומיאו ג'וליטה TURISMO  2016  1368 ליטר בנזין          39,000    2
#
#     gearBox       color original_onership next_test_in annual_licensing_fee  \
# 0   אוטומטי        אפור            ליסינג     ‏1,424 ₪                21999
# 1   אוטומטי        אפור             פרטית     2 חודשים             ‏1,424 ₪
# 2   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 3   אוטומטי  תכלת מטאלי             פרטית     1 חודשים             ‏2,019 ₪
# 4   אוטומטי         לבן             פרטית     3 חודשים             ‏1,962 ₪
# 5   אוטומטי         לבן             פרטית     1 חודשים             ‏1,369 ₪
# 6   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 7   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 8   אוטומטי        שחור             פרטית     3 חודשים             ‏1,508 ₪
# 9   אוטומטי        שחור             פרטית     4 חודשים             ‏1,962 ₪
# 10  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
# 11  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
# 12  אוטומטי         כסף            ליסינג    10 חודשים             ‏1,074 ₪
# 13  אוטומטי        אפור            ליסינג     3 חודשים             ‏1,693 ₪
# 14  אוטומטי         לבן             פרטית     4 חודשים             ‏2,019 ₪
#
#      price
# 0        0
# 1    59900
# 2    74900
# 3    74900
# 4   135000
# 5    11999
# 6    97000
# 7    97000
# 8    97000
# 9   140000
# 10   17500
# 11   17500
# 12   17500
# 13   69900
# 14   80000
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 13         מאזדה CX-5 EXECUTIVE  2013  1998 ליטר בנזין         149,000    3
# 14  אלפא רומיאו ג'וליטה TURISMO  2016  1368 ליטר בנזין          39,000    2
# 15       טויוטה אוריס HYBRID TS  2016  1798 ליטר בנזין         164,000    1
#
#     gearBox           color original_onership next_test_in  \
# 0   אוטומטי            אפור            ליסינג     ‏1,424 ₪
# 1   אוטומטי            אפור             פרטית     2 חודשים
# 2   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 3   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 4   אוטומטי             לבן             פרטית     3 חודשים
# 5   אוטומטי             לבן             פרטית     1 חודשים
# 6   אוטומטי            שחור             פרטית     3 חודשים
# 7   אוטומטי            שחור             פרטית     3 חודשים
# 8   אוטומטי            שחור             פרטית     3 חודשים
# 9   אוטומטי            שחור             פרטית     4 חודשים
# 10  אוטומטי             כסף            ליסינג    10 חודשים
# 11  אוטומטי             כסף            ליסינג    10 חודשים
# 12  אוטומטי             כסף            ליסינג    10 חודשים
# 13  אוטומטי            אפור            ליסינג     3 חודשים
# 14  אוטומטי             לבן             פרטית     4 חודשים
# 15  אוטומטי  אפור בהיר מטלי             פרטית     1 חודשים
#
#    annual_licensing_fee   price
# 0                 21999       0
# 1              ‏1,424 ₪   59900
# 2              ‏2,019 ₪   74900
# 3              ‏2,019 ₪   74900
# 4              ‏1,962 ₪  135000
# 5              ‏1,369 ₪   11999
# 6              ‏1,508 ₪   97000
# 7              ‏1,508 ₪   97000
# 8              ‏1,508 ₪   97000
# 9              ‏1,962 ₪  140000
# 10             ‏1,074 ₪   17500
# 11             ‏1,074 ₪   17500
# 12             ‏1,074 ₪   17500
# 13             ‏1,693 ₪   69900
# 14             ‏2,019 ₪   80000
# 15             ‏1,604 ₪   57750
# An exception occurred
# An exception occurred
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 13         מאזדה CX-5 EXECUTIVE  2013  1998 ליטר בנזין         149,000    3
# 14  אלפא רומיאו ג'וליטה TURISMO  2016  1368 ליטר בנזין          39,000    2
# 15       טויוטה אוריס HYBRID TS  2016  1798 ליטר בנזין         164,000    1
# 16            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
#
#     gearBox           color original_onership next_test_in  \
# 0   אוטומטי            אפור            ליסינג     ‏1,424 ₪
# 1   אוטומטי            אפור             פרטית     2 חודשים
# 2   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 3   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 4   אוטומטי             לבן             פרטית     3 חודשים
# 5   אוטומטי             לבן             פרטית     1 חודשים
# 6   אוטומטי            שחור             פרטית     3 חודשים
# 7   אוטומטי            שחור             פרטית     3 חודשים
# 8   אוטומטי            שחור             פרטית     3 חודשים
# 9   אוטומטי            שחור             פרטית     4 חודשים
# 10  אוטומטי             כסף            ליסינג    10 חודשים
# 11  אוטומטי             כסף            ליסינג    10 חודשים
# 12  אוטומטי             כסף            ליסינג    10 חודשים
# 13  אוטומטי            אפור            ליסינג     3 חודשים
# 14  אוטומטי             לבן             פרטית     4 חודשים
# 15  אוטומטי  אפור בהיר מטלי             פרטית     1 חודשים
# 16  אוטומטי             לבן            ליסינג     1 חודשים
#
#    annual_licensing_fee   price
# 0                 21999       0
# 1              ‏1,424 ₪   59900
# 2              ‏2,019 ₪   74900
# 3              ‏2,019 ₪   74900
# 4              ‏1,962 ₪  135000
# 5              ‏1,369 ₪   11999
# 6              ‏1,508 ₪   97000
# 7              ‏1,508 ₪   97000
# 8              ‏1,508 ₪   97000
# 9              ‏1,962 ₪  140000
# 10             ‏1,074 ₪   17500
# 11             ‏1,074 ₪   17500
# 12             ‏1,074 ₪   17500
# 13             ‏1,693 ₪   69900
# 14             ‏2,019 ₪   80000
# 15             ‏1,604 ₪   57750
# 16             ‏1,074 ₪   17500
# An exception occurred
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 13         מאזדה CX-5 EXECUTIVE  2013  1998 ליטר בנזין         149,000    3
# 14  אלפא רומיאו ג'וליטה TURISMO  2016  1368 ליטר בנזין          39,000    2
# 15       טויוטה אוריס HYBRID TS  2016  1798 ליטר בנזין         164,000    1
# 16            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
# 17            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
#
#     gearBox           color original_onership next_test_in  \
# 0   אוטומטי            אפור            ליסינג     ‏1,424 ₪
# 1   אוטומטי            אפור             פרטית     2 חודשים
# 2   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 3   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 4   אוטומטי             לבן             פרטית     3 חודשים
# 5   אוטומטי             לבן             פרטית     1 חודשים
# 6   אוטומטי            שחור             פרטית     3 חודשים
# 7   אוטומטי            שחור             פרטית     3 חודשים
# 8   אוטומטי            שחור             פרטית     3 חודשים
# 9   אוטומטי            שחור             פרטית     4 חודשים
# 10  אוטומטי             כסף            ליסינג    10 חודשים
# 11  אוטומטי             כסף            ליסינג    10 חודשים
# 12  אוטומטי             כסף            ליסינג    10 חודשים
# 13  אוטומטי            אפור            ליסינג     3 חודשים
# 14  אוטומטי             לבן             פרטית     4 חודשים
# 15  אוטומטי  אפור בהיר מטלי             פרטית     1 חודשים
# 16  אוטומטי             לבן            ליסינג     1 חודשים
# 17  אוטומטי             לבן            ליסינג     1 חודשים
#
#    annual_licensing_fee   price
# 0                 21999       0
# 1              ‏1,424 ₪   59900
# 2              ‏2,019 ₪   74900
# 3              ‏2,019 ₪   74900
# 4              ‏1,962 ₪  135000
# 5              ‏1,369 ₪   11999
# 6              ‏1,508 ₪   97000
# 7              ‏1,508 ₪   97000
# 8              ‏1,508 ₪   97000
# 9              ‏1,962 ₪  140000
# 10             ‏1,074 ₪   17500
# 11             ‏1,074 ₪   17500
# 12             ‏1,074 ₪   17500
# 13             ‏1,693 ₪   69900
# 14             ‏2,019 ₪   80000
# 15             ‏1,604 ₪   57750
# 16             ‏1,074 ₪   17500
# 17             ‏1,074 ₪   17500
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 13         מאזדה CX-5 EXECUTIVE  2013  1998 ליטר בנזין         149,000    3
# 14  אלפא רומיאו ג'וליטה TURISMO  2016  1368 ליטר בנזין          39,000    2
# 15       טויוטה אוריס HYBRID TS  2016  1798 ליטר בנזין         164,000    1
# 16            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
# 17            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
# 18     פורשה מקאן S ORCHID PACK  2016  2997 ליטר בנזין          80,000    5
#
#     gearBox           color original_onership next_test_in  \
# 0   אוטומטי            אפור            ליסינג     ‏1,424 ₪
# 1   אוטומטי            אפור             פרטית     2 חודשים
# 2   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 3   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 4   אוטומטי             לבן             פרטית     3 חודשים
# 5   אוטומטי             לבן             פרטית     1 חודשים
# 6   אוטומטי            שחור             פרטית     3 חודשים
# 7   אוטומטי            שחור             פרטית     3 חודשים
# 8   אוטומטי            שחור             פרטית     3 חודשים
# 9   אוטומטי            שחור             פרטית     4 חודשים
# 10  אוטומטי             כסף            ליסינג    10 חודשים
# 11  אוטומטי             כסף            ליסינג    10 חודשים
# 12  אוטומטי             כסף            ליסינג    10 חודשים
# 13  אוטומטי            אפור            ליסינג     3 חודשים
# 14  אוטומטי             לבן             פרטית     4 חודשים
# 15  אוטומטי  אפור בהיר מטלי             פרטית     1 חודשים
# 16  אוטומטי             לבן            ליסינג     1 חודשים
# 17  אוטומטי             לבן            ליסינג     1 חודשים
# 18  אוטומטי       שחור מטלי             פרטית     3 חודשים
#
#    annual_licensing_fee   price
# 0                 21999       0
# 1              ‏1,424 ₪   59900
# 2              ‏2,019 ₪   74900
# 3              ‏2,019 ₪   74900
# 4              ‏1,962 ₪  135000
# 5              ‏1,369 ₪   11999
# 6              ‏1,508 ₪   97000
# 7              ‏1,508 ₪   97000
# 8              ‏1,508 ₪   97000
# 9              ‏1,962 ₪  140000
# 10             ‏1,074 ₪   17500
# 11             ‏1,074 ₪   17500
# 12             ‏1,074 ₪   17500
# 13             ‏1,693 ₪   69900
# 14             ‏2,019 ₪   80000
# 15             ‏1,604 ₪   57750
# 16             ‏1,074 ₪   17500
# 17             ‏1,074 ₪   17500
# 18             ‏3,357 ₪  270000
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 13         מאזדה CX-5 EXECUTIVE  2013  1998 ליטר בנזין         149,000    3
# 14  אלפא רומיאו ג'וליטה TURISMO  2016  1368 ליטר בנזין          39,000    2
# 15       טויוטה אוריס HYBRID TS  2016  1798 ליטר בנזין         164,000    1
# 16            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
# 17            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
# 18     פורשה מקאן S ORCHID PACK  2016  2997 ליטר בנזין          80,000    5
# 19     פורשה מקאן S ORCHID PACK  2016  2997 ליטר בנזין          80,000    5
#
#     gearBox           color original_onership next_test_in  \
# 0   אוטומטי            אפור            ליסינג     ‏1,424 ₪
# 1   אוטומטי            אפור             פרטית     2 חודשים
# 2   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 3   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 4   אוטומטי             לבן             פרטית     3 חודשים
# 5   אוטומטי             לבן             פרטית     1 חודשים
# 6   אוטומטי            שחור             פרטית     3 חודשים
# 7   אוטומטי            שחור             פרטית     3 חודשים
# 8   אוטומטי            שחור             פרטית     3 חודשים
# 9   אוטומטי            שחור             פרטית     4 חודשים
# 10  אוטומטי             כסף            ליסינג    10 חודשים
# 11  אוטומטי             כסף            ליסינג    10 חודשים
# 12  אוטומטי             כסף            ליסינג    10 חודשים
# 13  אוטומטי            אפור            ליסינג     3 חודשים
# 14  אוטומטי             לבן             פרטית     4 חודשים
# 15  אוטומטי  אפור בהיר מטלי             פרטית     1 חודשים
# 16  אוטומטי             לבן            ליסינג     1 חודשים
# 17  אוטומטי             לבן            ליסינג     1 חודשים
# 18  אוטומטי       שחור מטלי             פרטית     3 חודשים
# 19  אוטומטי       שחור מטלי             פרטית     3 חודשים
#
#    annual_licensing_fee   price
# 0                 21999       0
# 1              ‏1,424 ₪   59900
# 2              ‏2,019 ₪   74900
# 3              ‏2,019 ₪   74900
# 4              ‏1,962 ₪  135000
# 5              ‏1,369 ₪   11999
# 6              ‏1,508 ₪   97000
# 7              ‏1,508 ₪   97000
# 8              ‏1,508 ₪   97000
# 9              ‏1,962 ₪  140000
# 10             ‏1,074 ₪   17500
# 11             ‏1,074 ₪   17500
# 12             ‏1,074 ₪   17500
# 13             ‏1,693 ₪   69900
# 14             ‏2,019 ₪   80000
# 15             ‏1,604 ₪   57750
# 16             ‏1,074 ₪   17500
# 17             ‏1,074 ₪   17500
# 18             ‏3,357 ₪  270000
# 19             ‏3,357 ₪  270000
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 13         מאזדה CX-5 EXECUTIVE  2013  1998 ליטר בנזין         149,000    3
# 14  אלפא רומיאו ג'וליטה TURISMO  2016  1368 ליטר בנזין          39,000    2
# 15       טויוטה אוריס HYBRID TS  2016  1798 ליטר בנזין         164,000    1
# 16            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
# 17            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
# 18     פורשה מקאן S ORCHID PACK  2016  2997 ליטר בנזין          80,000    5
# 19     פורשה מקאן S ORCHID PACK  2016  2997 ליטר בנזין          80,000    5
# 20     פורשה מקאן S ORCHID PACK  2016  2997 ליטר בנזין          80,000    5
#
#     gearBox           color original_onership next_test_in  \
# 0   אוטומטי            אפור            ליסינג     ‏1,424 ₪
# 1   אוטומטי            אפור             פרטית     2 חודשים
# 2   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 3   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 4   אוטומטי             לבן             פרטית     3 חודשים
# 5   אוטומטי             לבן             פרטית     1 חודשים
# 6   אוטומטי            שחור             פרטית     3 חודשים
# 7   אוטומטי            שחור             פרטית     3 חודשים
# 8   אוטומטי            שחור             פרטית     3 חודשים
# 9   אוטומטי            שחור             פרטית     4 חודשים
# 10  אוטומטי             כסף            ליסינג    10 חודשים
# 11  אוטומטי             כסף            ליסינג    10 חודשים
# 12  אוטומטי             כסף            ליסינג    10 חודשים
# 13  אוטומטי            אפור            ליסינג     3 חודשים
# 14  אוטומטי             לבן             פרטית     4 חודשים
# 15  אוטומטי  אפור בהיר מטלי             פרטית     1 חודשים
# 16  אוטומטי             לבן            ליסינג     1 חודשים
# 17  אוטומטי             לבן            ליסינג     1 חודשים
# 18  אוטומטי       שחור מטלי             פרטית     3 חודשים
# 19  אוטומטי       שחור מטלי             פרטית     3 חודשים
# 20  אוטומטי       שחור מטלי             פרטית     3 חודשים
#
#    annual_licensing_fee   price
# 0                 21999       0
# 1              ‏1,424 ₪   59900
# 2              ‏2,019 ₪   74900
# 3              ‏2,019 ₪   74900
# 4              ‏1,962 ₪  135000
# 5              ‏1,369 ₪   11999
# 6              ‏1,508 ₪   97000
# 7              ‏1,508 ₪   97000
# 8              ‏1,508 ₪   97000
# 9              ‏1,962 ₪  140000
# 10             ‏1,074 ₪   17500
# 11             ‏1,074 ₪   17500
# 12             ‏1,074 ₪   17500
# 13             ‏1,693 ₪   69900
# 14             ‏2,019 ₪   80000
# 15             ‏1,604 ₪   57750
# 16             ‏1,074 ₪   17500
# 17             ‏1,074 ₪   17500
# 18             ‏3,357 ₪  270000
# 19             ‏3,357 ₪  270000
# 20             ‏3,357 ₪  270000
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 4   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין          66,000    2
# 5          טויוטה אוונסיס GLI-S  2006  1998 ליטר בנזין         261,000    3
# 6     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 7     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 8     ג'יפ גראנד צ'ירוקי LAREDO  2011  3604 ליטר בנזין         218,000    2
# 9   מרצדס CLA קלאס CLA200 URBAN  2015  1595 ליטר בנזין         135,000    4
# 10              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 11              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 12              יונדאי אקסנט GL  2010  1399 ליטר בנזין         169,000    3
# 13         מאזדה CX-5 EXECUTIVE  2013  1998 ליטר בנזין         149,000    3
# 14  אלפא רומיאו ג'וליטה TURISMO  2016  1368 ליטר בנזין          39,000    2
# 15       טויוטה אוריס HYBRID TS  2016  1798 ליטר בנזין         164,000    1
# 16            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
# 17            דייהטסו סיריון CX  2010  1298 ליטר בנזין         205,000    3
# 18     פורשה מקאן S ORCHID PACK  2016  2997 ליטר בנזין          80,000    5
# 19     פורשה מקאן S ORCHID PACK  2016  2997 ליטר בנזין          80,000    5
# 20     פורשה מקאן S ORCHID PACK  2016  2997 ליטר בנזין          80,000    5
# 21        מרצדס C קלאס C250 AMG  2015  1991 ליטר בנזין          85,000    4
#
#     gearBox           color original_onership next_test_in  \
# 0   אוטומטי            אפור            ליסינג     ‏1,424 ₪
# 1   אוטומטי            אפור             פרטית     2 חודשים
# 2   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 3   אוטומטי      תכלת מטאלי             פרטית     1 חודשים
# 4   אוטומטי             לבן             פרטית     3 חודשים
# 5   אוטומטי             לבן             פרטית     1 חודשים
# 6   אוטומטי            שחור             פרטית     3 חודשים
# 7   אוטומטי            שחור             פרטית     3 חודשים
# 8   אוטומטי            שחור             פרטית     3 חודשים
# 9   אוטומטי            שחור             פרטית     4 חודשים
# 10  אוטומטי             כסף            ליסינג    10 חודשים
# 11  אוטומטי             כסף            ליסינג    10 חודשים
# 12  אוטומטי             כסף            ליסינג    10 חודשים
# 13  אוטומטי            אפור            ליסינג     3 חודשים
# 14  אוטומטי             לבן             פרטית     4 חודשים
# 15  אוטומטי  אפור בהיר מטלי             פרטית     1 חודשים
# 16  אוטומטי             לבן            ליסינג     1 חודשים
# 17  אוטומטי             לבן            ליסינג     1 חודשים
# 18  אוטומטי       שחור מטלי             פרטית     3 חודשים
# 19  אוטומטי       שחור מטלי             פרטית     3 חודשים
# 20  אוטומטי       שחור מטלי             פרטית     3 חודשים
# 21  אוטומטי             לבן             פרטית     4 חודשים
#
#    annual_licensing_fee   price
# 0                 21999       0
# 1              ‏1,424 ₪   59900
# 2              ‏2,019 ₪   74900
# 3              ‏2,019 ₪   74900
# 4              ‏1,962 ₪  135000
# 5              ‏1,369 ₪   11999
# 6              ‏1,508 ₪   97000
# 7              ‏1,508 ₪   97000
# 8              ‏1,508 ₪   97000
# 9              ‏1,962 ₪  140000
# 10             ‏1,074 ₪   17500
# 11             ‏1,074 ₪   17500
# 12             ‏1,074 ₪   17500
# 13             ‏1,693 ₪   69900
# 14             ‏2,019 ₪   80000
# 15             ‏1,604 ₪   57750
# 16             ‏1,074 ₪   17500
# 17             ‏1,074 ₪   17500
# 18             ‏3,357 ₪  270000
# 19             ‏3,357 ₪  270000
# 20             ‏3,357 ₪  270000
# 21             ‏2,397 ₪  175000
#                         version  year           engine current_mileage hand  \
# 0              פורד פוקוס TREND  2013  1596 ליטר בנזין         183,000    2
# 1          ניסאן ג'וק TEKNA P.D  2015  1598 ליטר בנזין          75,000    2
# 2         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# 3         סובארו XV 2.0 PREMIUM  2016  1995 ליטר בנזין         179,000    1
# ...
# 231               יונדאי IX35 PRIME  2014  1999 ליטר בנזין         115,000
# 232              יונדאי I35 SUPREME  2015  1591 ליטר בנזין          95,000
# 233               סקודה קארוק STYLE  2019  1498 ליטר בנזין          52,686
# 234                     קיה נירו EX  2017  1580 ליטר בנזין         108,840
# 235  מרצדס CLA קלאס CLA180 URBAN FL  2017  1595 ליטר בנזין          70,000
#
#     hand  gearBox       color original_onership next_test_in  \
# 0      2  אוטומטי        אפור            ליסינג     ‏1,424 ₪
# 1      2  אוטומטי        אפור             פרטית     2 חודשים
# 2      1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 3      1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 4      2  אוטומטי         לבן             פרטית     3 חודשים
# ..   ...      ...         ...               ...          ...
# 231    1  אוטומטי   כסוף בהיר             פרטית    12 חודשים
# 232    2  אוטומטי    כסף מטלי             פרטית    12 חודשים
# 233    1  אוטומטי  אפור מטאלי             פרטית    11 חודשים
# 234    2  אוטומטי        אפור             פרטית     2 חודשים
# 235    1  אוטומטי         לבן             פרטית     4 חודשים
#
#     annual_licensing_fee   price
# 0                  21999       0
# 1               ‏1,424 ₪   59900
# 2               ‏2,019 ₪   74900
# 3               ‏2,019 ₪   74900
# 4               ‏1,962 ₪  135000
# ..                   ...     ...
# 231             ‏1,584 ₪   68500
# 232             ‏1,424 ₪   58000
# 233             ‏1,835 ₪  144900
# 234             ‏1,604 ₪  103900
# 235             ‏2,563 ₪  159000
#
# [236 rows x 11 columns]
#                                      version  year                engine  \
# 0                           פורד פוקוס TREND  2013       1596 ליטר בנזין
# 1                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 2                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 3                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 4                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# ..                                       ...   ...                   ...
# 232                       יונדאי I35 SUPREME  2015       1591 ליטר בנזין
# 233                        סקודה קארוק STYLE  2019       1498 ליטר בנזין
# 234                              קיה נירו EX  2017       1580 ליטר בנזין
# 235           מרצדס CLA קלאס CLA180 URBAN FL  2017       1595 ליטר בנזין
# 236  ב.מ.וו סדרה 3 330E IPERFORMAN EXCLUSIVE  2018  1998 ליטר חשמל/בנזין
#
#     current_mileage hand  gearBox       color original_onership next_test_in  \
# 0           183,000    2  אוטומטי        אפור            ליסינג     ‏1,424 ₪
# 1            75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 2           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 3           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 4            66,000    2  אוטומטי         לבן             פרטית     3 חודשים
# ..              ...  ...      ...         ...               ...          ...
# 232          95,000    2  אוטומטי    כסף מטלי             פרטית    12 חודשים
# 233          52,686    1  אוטומטי  אפור מטאלי             פרטית    11 חודשים
# 234         108,840    2  אוטומטי        אפור             פרטית     2 חודשים
# 235          70,000    1  אוטומטי         לבן             פרטית     4 חודשים
# 236          58,000    1  אוטומטי         לבן             פרטית     8 חודשים
#
#     annual_licensing_fee   price
# 0                  21999       0
# 1               ‏1,424 ₪   59900
# 2               ‏2,019 ₪   74900
# 3               ‏2,019 ₪   74900
# 4               ‏1,962 ₪  135000
# ..                   ...     ...
# 232             ‏1,424 ₪   58000
# 233             ‏1,835 ₪  144900
# 234             ‏1,604 ₪  103900
# 235             ‏2,563 ₪  159000
# 236             ‏2,563 ₪  199500
#
# [237 rows x 11 columns]
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
#                                      version  year                engine  \
# 0                           פורד פוקוס TREND  2013       1596 ליטר בנזין
# 1                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 2                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 3                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 4                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# ..                                       ...   ...                   ...
# 233                        סקודה קארוק STYLE  2019       1498 ליטר בנזין
# 234                              קיה נירו EX  2017       1580 ליטר בנזין
# 235           מרצדס CLA קלאס CLA180 URBAN FL  2017       1595 ליטר בנזין
# 236  ב.מ.וו סדרה 3 330E IPERFORMAN EXCLUSIVE  2018  1998 ליטר חשמל/בנזין
# 237                            קיה פיקנטו LX  2017       1248 ליטר בנזין
#
#     current_mileage hand  gearBox       color original_onership next_test_in  \
# 0           183,000    2  אוטומטי        אפור            ליסינג     ‏1,424 ₪
# 1            75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 2           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 3           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 4            66,000    2  אוטומטי         לבן             פרטית     3 חודשים
# ..              ...  ...      ...         ...               ...          ...
# 233          52,686    1  אוטומטי  אפור מטאלי             פרטית    11 חודשים
# 234         108,840    2  אוטומטי        אפור             פרטית     2 חודשים
# 235          70,000    1  אוטומטי         לבן             פרטית     4 חודשים
# 236          58,000    1  אוטומטי         לבן             פרטית     8 חודשים
# 237          53,229    2  אוטומטי  כסוף מטאלי             פרטית     6 חודשים
#
#     annual_licensing_fee   price
# 0                  21999       0
# 1               ‏1,424 ₪   59900
# 2               ‏2,019 ₪   74900
# 3               ‏2,019 ₪   74900
# 4               ‏1,962 ₪  135000
# ..                   ...     ...
# 233             ‏1,835 ₪  144900
# 234             ‏1,604 ₪  103900
# 235             ‏2,563 ₪  159000
# 236             ‏2,563 ₪  199500
# 237             ‏1,102 ₪   64900
#
# [238 rows x 11 columns]
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
#                                      version  year                engine  \
# 0                           פורד פוקוס TREND  2013       1596 ליטר בנזין
# 1                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 2                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 3                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 4                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# ..                                       ...   ...                   ...
# 234                              קיה נירו EX  2017       1580 ליטר בנזין
# 235           מרצדס CLA קלאס CLA180 URBAN FL  2017       1595 ליטר בנזין
# 236  ב.מ.וו סדרה 3 330E IPERFORMAN EXCLUSIVE  2018  1998 ליטר חשמל/בנזין
# 237                            קיה פיקנטו LX  2017       1248 ליטר בנזין
# 238                          שברולט ספארק LT  2016       1399 ליטר בנזין
#
#     current_mileage hand  gearBox       color original_onership next_test_in  \
# 0           183,000    2  אוטומטי        אפור            ליסינג     ‏1,424 ₪
# 1            75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 2           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 3           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 4            66,000    2  אוטומטי         לבן             פרטית     3 חודשים
# ..              ...  ...      ...         ...               ...          ...
# 234         108,840    2  אוטומטי        אפור             פרטית     2 חודשים
# 235          70,000    1  אוטומטי         לבן             פרטית     4 חודשים
# 236          58,000    1  אוטומטי         לבן             פרטית     8 חודשים
# 237          53,229    2  אוטומטי  כסוף מטאלי             פרטית     6 חודשים
# 238          59,582    2  אוטומטי         לבן             פרטית     6 חודשים
#
#     annual_licensing_fee   price
# 0                  21999       0
# 1               ‏1,424 ₪   59900
# 2               ‏2,019 ₪   74900
# 3               ‏2,019 ₪   74900
# 4               ‏1,962 ₪  135000
# ..                   ...     ...
# 234             ‏1,604 ₪  103900
# 235             ‏2,563 ₪  159000
# 236             ‏2,563 ₪  199500
# 237             ‏1,102 ₪   64900
# 238             ‏1,102 ₪   66900
#
# [239 rows x 11 columns]
#                                      version  year                engine  \
# 0                           פורד פוקוס TREND  2013       1596 ליטר בנזין
# 1                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 2                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 3                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 4                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# ..                                       ...   ...                   ...
# 235           מרצדס CLA קלאס CLA180 URBAN FL  2017       1595 ליטר בנזין
# 236  ב.מ.וו סדרה 3 330E IPERFORMAN EXCLUSIVE  2018  1998 ליטר חשמל/בנזין
# 237                            קיה פיקנטו LX  2017       1248 ליטר בנזין
# 238                          שברולט ספארק LT  2016       1399 ליטר בנזין
# 239                         יונדאי I10 PRIME  2019       1248 ליטר בנזין
#
#     current_mileage hand  gearBox       color original_onership next_test_in  \
# 0           183,000    2  אוטומטי        אפור            ליסינג     ‏1,424 ₪
# 1            75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 2           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 3           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 4            66,000    2  אוטומטי         לבן             פרטית     3 חודשים
# ..              ...  ...      ...         ...               ...          ...
# 235          70,000    1  אוטומטי         לבן             פרטית     4 חודשים
# 236          58,000    1  אוטומטי         לבן             פרטית     8 חודשים
# 237          53,229    2  אוטומטי  כסוף מטאלי             פרטית     6 חודשים
# 238          59,582    2  אוטומטי         לבן             פרטית     6 חודשים
# 239          24,500    1  אוטומטי        שחור             פרטית    11 חודשים
#
#     annual_licensing_fee   price
# 0                  21999       0
# 1               ‏1,424 ₪   59900
# 2               ‏2,019 ₪   74900
# 3               ‏2,019 ₪   74900
# 4               ‏1,962 ₪  135000
# ..                   ...     ...
# 235             ‏2,563 ₪  159000
# 236             ‏2,563 ₪  199500
# 237             ‏1,102 ₪   64900
# 238             ‏1,102 ₪   66900
# 239             ‏1,102 ₪   68500
#
# [240 rows x 11 columns]
#                                        version  year                engine  \
# 0                             פורד פוקוס TREND  2013       1596 ליטר בנזין
# 1                         ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 2                        סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 3                        סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 4                  מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# ..                                         ...   ...                   ...
# 236    ב.מ.וו סדרה 3 330E IPERFORMAN EXCLUSIVE  2018  1998 ליטר חשמל/בנזין
# 237                              קיה פיקנטו LX  2017       1248 ליטר בנזין
# 238                            שברולט ספארק LT  2016       1399 ליטר בנזין
# 239                           יונדאי I10 PRIME  2019       1248 ליטר בנזין
# 240  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
#
#     current_mileage hand  gearBox       color original_onership next_test_in  \
# 0           183,000    2  אוטומטי        אפור            ליסינג     ‏1,424 ₪
# 1            75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 2           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 3           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 4            66,000    2  אוטומטי         לבן             פרטית     3 חודשים
# ..              ...  ...      ...         ...               ...          ...
# 236          58,000    1  אוטומטי         לבן             פרטית     8 חודשים
# 237          53,229    2  אוטומטי  כסוף מטאלי             פרטית     6 חודשים
# 238          59,582    2  אוטומטי         לבן             פרטית     6 חודשים
# 239          24,500    1  אוטומטי        שחור             פרטית    11 חודשים
# 240          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
#
#     annual_licensing_fee   price
# 0                  21999       0
# 1               ‏1,424 ₪   59900
# 2               ‏2,019 ₪   74900
# 3               ‏2,019 ₪   74900
# 4               ‏1,962 ₪  135000
# ..                   ...     ...
# 236             ‏2,563 ₪  199500
# 237             ‏1,102 ₪   64900
# 238             ‏1,102 ₪   66900
# 239             ‏1,102 ₪   68500
# 240             ‏4,731 ₪  330000
#
# [241 rows x 11 columns]
#                                        version  year                engine  \
# 0                             פורד פוקוס TREND  2013       1596 ליטר בנזין
# 1                         ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 2                        סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 3                        סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 4                  מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# ..                                         ...   ...                   ...
# 236    ב.מ.וו סדרה 3 330E IPERFORMAN EXCLUSIVE  2018  1998 ליטר חשמל/בנזין
# 237                              קיה פיקנטו LX  2017       1248 ליטר בנזין
# 238                            שברולט ספארק LT  2016       1399 ליטר בנזין
# 239                           יונדאי I10 PRIME  2019       1248 ליטר בנזין
# 240  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
#
#     current_mileage hand  gearBox       color original_onership next_test_in  \
# 0           183,000    2  אוטומטי        אפור            ליסינג     ‏1,424 ₪
# 1            75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 2           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 3           179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 4            66,000    2  אוטומטי         לבן             פרטית     3 חודשים
# ..              ...  ...      ...         ...               ...          ...
# 236          58,000    1  אוטומטי         לבן             פרטית     8 חודשים
# 237          53,229    2  אוטומטי  כסוף מטאלי             פרטית     6 חודשים
# 238          59,582    2  אוטומטי         לבן             פרטית     6 חודשים
# 239          24,500    1  אוטומטי        שחור             פרטית    11 חודשים
# 240          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
#
#     annual_licensing_fee   price
# 0                  21999       0
# 1               ‏1,424 ₪   59900
# 2               ‏2,019 ₪   74900
# 3               ‏2,019 ₪   74900
# 4               ‏1,962 ₪  135000
# ..                   ...     ...
# 236             ‏2,563 ₪  199500
# 237             ‏1,102 ₪   64900
# 238             ‏1,102 ₪   66900
# 239             ‏1,102 ₪   68500
# 240             ‏4,731 ₪  330000
#
# [241 rows x 11 columns]

# %%
df_Det.to_csv('cars_data.csv' , index_label='index' )

# %%
cars = pd.read_csv(r'C:\Users\avoav\Introduction to Data Science\Project סמסטר א\project-semester-a\cars_data.csv')

# %%
cars.version.unique()
#we saw here that we need to split the "version" column to two columns : "CompanyName" and "version":
CompanyName = cars['version'].apply(lambda x : x.split(' ')[0])
cars.insert(1,"CompanyName",CompanyName)

# %%
#cars = cars.drop(columns=[ 'index' ]  )
cars
# Out:
#     CompanyName                                    version  year  \
# 0          פורד                           פורד פוקוס TREND  2013
# 1         ניסאן                       ניסאן ג'וק TEKNA P.D  2015
# 2        סובארו                      סובארו XV 2.0 PREMIUM  2016
# 3        סובארו                      סובארו XV 2.0 PREMIUM  2016
# 4         מרצדס                מרצדס CLA קלאס CLA200 URBAN  2015
# ..          ...                                        ...   ...
# 236      ב.מ.וו    ב.מ.וו סדרה 3 330E IPERFORMAN EXCLUSIVE  2018
# 237         קיה                              קיה פיקנטו LX  2017
# 238      שברולט                            שברולט ספארק LT  2016
# 239      יונדאי                           יונדאי I10 PRIME  2019
# 240      ב.מ.וו  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019
#
#                    engine current_mileage  hand  gearBox       color  \
# 0         1596 ליטר בנזין         183,000     2  אוטומטי        אפור
# 1         1598 ליטר בנזין          75,000     2  אוטומטי        אפור
# 2         1995 ליטר בנזין         179,000     1  אוטומטי  תכלת מטאלי
# 3         1995 ליטר בנזין         179,000     1  אוטומטי  תכלת מטאלי
# 4         1595 ליטר בנזין          66,000     2  אוטומטי         לבן
# ..                    ...             ...   ...      ...         ...
# 236  1998 ליטר חשמל/בנזין          58,000     1  אוטומטי         לבן
# 237       1248 ליטר בנזין          53,229     2  אוטומטי  כסוף מטאלי
# 238       1399 ליטר בנזין          59,582     2  אוטומטי         לבן
# 239       1248 ליטר בנזין          24,500     1  אוטומטי        שחור
# 240  1998 ליטר חשמל/בנזין          50,000     1  אוטומטי   אפור פלדה
#
#     original_onership next_test_in annual_licensing_fee   price
# 0              ליסינג     ‏1,424 ₪                21999       0
# 1               פרטית     2 חודשים             ‏1,424 ₪   59900
# 2               פרטית     1 חודשים             ‏2,019 ₪   74900
# 3               פרטית     1 חודשים             ‏2,019 ₪   74900
# 4               פרטית     3 חודשים             ‏1,962 ₪  135000
# ..                ...          ...                  ...     ...
# 236             פרטית     8 חודשים             ‏2,563 ₪  199500
# 237             פרטית     6 חודשים             ‏1,102 ₪   64900
# 238             פרטית     6 חודשים             ‏1,102 ₪   66900
# 239             פרטית    11 חודשים             ‏1,102 ₪   68500
# 240        ייבוא אישי     5 חודשים             ‏4,731 ₪  330000
#
# [241 rows x 12 columns]

# %%
car_names = cars.CompanyName.unique()
car_names
# Out:
# array(['פורד', 'ניסאן', 'סובארו', 'מרצדס', 'טויוטה', "ג'יפ", 'יונדאי',
#        'מאזדה', 'אלפא', 'דייהטסו', 'פורשה', 'פיאט', 'סיטרואן', 'סוזוקי',
#        "דאצ'יה", 'ב.מ.וו', 'סיאט', "פיג'ו", 'פולקסווגן', 'רנו', 'הונדה',
#        'אאודי', 'סקודה', 'מיצובישי', 'מיני', 'אינפיניטי', 'קיה', 'לנד',
#        'שברולט'], dtype=object)

# %%
#there is some names we want to set right:
# לנד == לנד רובר
# אלפא = אלפא רומיאו
#we also need to change all names to english so we do that together:

car_names = cars.CompanyName.unique()
i=0
for item in car_names:
    if (item == "אלפא"): 
        car_names[i] = 'alfa-romeo'  
    elif (item =='ניסאן'): 
        car_names[i] = 'nissan'
    elif (item == "מאזדה"): 
        car_names[i] = 'mazda'
    elif (item == "סובארו"): 
        car_names[i] = 'subaru'
    elif (item == "מרצדס"): 
        car_names[i] = 'mercedes'
    elif (item == "סיאט"): 
        car_names[i] = 'siat'   
    elif (item == "סיטרואן"): 
        car_names[i] = 'citroen'   
    elif (item == "טויוטה"): 
        car_names[i] = 'toyota'   
    elif (item =="ג'יפ"): 
        car_names[i] = 'jeep'   
    elif (item == "קיה"): 
        car_names[i] = 'kia'   
    elif (item == "יונדאי"): 
        car_names[i] = 'hyundai'   
    elif (item == "דייהטסו"): 
        car_names[i] = 'daihatsu'   
    elif (item == "פורשה"): 
        car_names[i] = 'porsche'   
    elif (item == "פיאט"): 
        car_names[i] = 'fiat'   
    elif (item == "פורד"): 
        car_names[i] = 'ford'   
    elif (item == "סוזוקי"): 
        car_names[i] = 'suzuki'   
    elif (item == "דאצ'יה"): 
        car_names[i] = 'dacia'   
    elif (item == "ב.מ.וו"): 
        car_names[i] = 'bmw'   
    elif (item == "פיג'ו"): 
        car_names[i] = 'peugeot'   
    elif (item == "מיצובישי"): 
        car_names[i] = 'mitsubishi'   
    elif (item == "פולקסווגן"): 
        car_names[i] = 'volkswagen'   
    elif (item == "רנו"): 
        car_names[i] = 'reno' 
    elif (item == "הונדה"): 
        car_names[i] = 'honda' 
    elif (item == "אאודי"): 
        car_names[i] = 'audi' 
    elif (item == "סקודה"): 
        car_names[i] = 'skoda' 
    elif (item == "מיני"): 
        car_names[i] = 'mini' 
    elif (item == "אינפיניטי"): 
        car_names[i] = 'infinity'
    elif (item == "לנד"): 
        car_names[i] = 'landrover' 
    elif (item == "שברולט"): 
        car_names[i] = 'chevrolet'
    elif (item == "אופל"): 
        car_names[i] = 'opel'
    elif (item == "MG"): 
        car_names[i] = 'MG'
    elif (item == "טסלה"): 
        car_names[i] = 'tesla'
    elif (item == "'דודג"): 
        car_names[i] = 'dodge'
    elif (item == "ביואיק"): 
        car_names[i] = 'buick'
    elif (item == "יגואר"): 
        car_names[i] = 'jaguar'   
    elif (item == "לקסוס"): 
        car_names[i] = 'lexus' 
    elif (item == "סמארט"): 
        car_names[i] = 'smart'
    elif (item == "סאנגיונג"): 
        car_names[i] = 'sangiang'
    elif (item == "קאדילק"): 
        car_names[i] = 'cadillac'
    elif (item == "קופרה"): 
        car_names[i] = 'cupra'   
    elif (item == "קרייזלר"): 
        car_names[i] = 'chrysler'
    elif (item == "מזארטי"): 
        car_names[i] = 'maserati' 
    elif (item == "וולבו"): 
        car_names[i] = 'volvo'
    elif (item == "איסוזו"): 
        car_names[i] = 'isuzu'
    elif (item == "GMC"): 
        car_names[i] = 'gmc'   
    else:
        item = "mazda" # one of the popular cars... 
    i= i+1   


print(car_names)
# Out:
# ['ford' 'nissan' 'subaru' 'mercedes' 'toyota' 'jeep' 'hyundai' 'mazda'
#  'alfa-romeo' 'daihatsu' 'porsche' 'fiat' 'citroen' 'suzuki' 'dacia' 'bmw'
#  'siat' 'peugeot' 'volkswagen' 'reno' 'honda' 'audi' 'skoda' 'mitsubishi'
#  'mini' 'infinity' 'kia' 'landrover' 'chevrolet']

# %%
# now, we want to change the column "CompanyName" :
def item_to_E (item):
    if (item in car_names):
        return item
    if (item == "אלפא"): 
        item = 'alfa-romeo'  
    elif (item =='ניסאן'): 
        item = 'nissan'
    elif (item == "מאזדה"): 
        item = 'mazda'
    elif (item == "סובארו"): 
        item = 'subaru'
    elif (item == "מרצדס"): 
        item = 'mercedes'
    elif (item == "סיאט"): 
        item = 'siat'   
    elif (item == "סיטרואן"): 
        item = 'citroen'   
    elif (item == "טויוטה"): 
        item = 'toyota'   
    elif (item =="ג'יפ"): 
        item = 'jeep'   
    elif (item == "קיה"): 
        item = 'kia'   
    elif (item == "יונדאי"): 
        item = 'hyundai'   
    elif (item == "דייהטסו"): 
        item = 'daihatsu'   
    elif (item == "פורשה"): 
        item = 'porsche'   
    elif (item == "פיאט"): 
        item = 'fiat'   
    elif (item == "פורד"): 
        item = 'ford'   
    elif (item == "סוזוקי"): 
        item = 'suzuki'   
    elif (item == "דאצ'יה"): 
        item = 'dacia'   
    elif (item == "ב.מ.וו"): 
        item = 'bmw'   
    elif (item == "פיג'ו"): 
        item = 'peugeot'   
    elif (item == "מיצובישי"): 
        item = 'mitsubishi'   
    elif (item == "פולקסווגן"): 
        item = 'volkswagen'   
    elif (item == "רנו"): 
        item = 'reno' 
    elif (item == "הונדה"): 
        item = 'honda' 
    elif (item == "אאודי"): 
        item = 'audi' 
    elif (item == "סקודה"): 
        item = 'skoda' 
    elif (item == "מיני"): 
        item = 'mini' 
    elif (item == "אינפיניטי"): 
        item = 'infinity'
    elif (item == "לנד"): 
        item = 'landrover' 
    elif (item == "שברולט"): 
        item = 'chevrolet'
    elif (item == "אופל"): 
        item = 'opel'
    elif (item == "MG"): 
        item = 'MG'
    elif (item == "טסלה"): 
        item = 'tesla'
    elif (item == "'דודג"): 
        item = 'dodge'
    elif (item == "ביואיק"): 
        item = 'buick'
    elif (item == "יגואר"): 
        item = 'jaguar'   
    elif (item == "לקסוס"): 
        item = 'lexus' 
    elif (item == "סמארט"): 
        item = 'smart'
    elif (item == "סאנגיונג"): 
        item = 'sangiang'
    elif (item == "קאדילק"): 
        item = 'cadillac'
    elif (item == "קופרה"): 
        item = 'cupra'   
    elif (item == "קרייזלר"): 
        item = 'chrysler'
    elif (item == "מזארטי"): 
        item = 'maserati' 
    elif (item == "וולבו"): 
        item = 'volvo'
    elif (item == "איסוזו"): 
        item = 'isuzu'
    elif (item == "GMC"): 
        item = 'gmc'
    else:
        item = "mazda" # one of the popular cars... 
    return item

cars['CompanyName'].apply(item_to_E)
# Out:
# 0           ford
# 1         nissan
# 2         subaru
# 3         subaru
# 4       mercedes
#          ...
# 236          bmw
# 237          kia
# 238    chevrolet
# 239      hyundai
# 240          bmw
# Name: CompanyName, Length: 241, dtype: object

# %%
cars['CompanyName']
# Out:
#     CompanyName                                    version  year  \
# 0          פורד                           פורד פוקוס TREND  2013
# 1         ניסאן                       ניסאן ג'וק TEKNA P.D  2015
# 2        סובארו                      סובארו XV 2.0 PREMIUM  2016
# 3        סובארו                      סובארו XV 2.0 PREMIUM  2016
# 4         מרצדס                מרצדס CLA קלאס CLA200 URBAN  2015
# ..          ...                                        ...   ...
# 236      ב.מ.וו    ב.מ.וו סדרה 3 330E IPERFORMAN EXCLUSIVE  2018
# 237         קיה                              קיה פיקנטו LX  2017
# 238      שברולט                            שברולט ספארק LT  2016
# 239      יונדאי                           יונדאי I10 PRIME  2019
# 240      ב.מ.וו  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019
#
#                    engine current_mileage  hand  gearBox       color  \
# 0         1596 ליטר בנזין         183,000     2  אוטומטי        אפור
# 1         1598 ליטר בנזין          75,000     2  אוטומטי        אפור
# 2         1995 ליטר בנזין         179,000     1  אוטומטי  תכלת מטאלי
# 3         1995 ליטר בנזין         179,000     1  אוטומטי  תכלת מטאלי
# 4         1595 ליטר בנזין          66,000     2  אוטומטי         לבן
# ..                    ...             ...   ...      ...         ...
# 236  1998 ליטר חשמל/בנזין          58,000     1  אוטומטי         לבן
# 237       1248 ליטר בנזין          53,229     2  אוטומטי  כסוף מטאלי
# 238       1399 ליטר בנזין          59,582     2  אוטומטי         לבן
# 239       1248 ליטר בנזין          24,500     1  אוטומטי        שחור
# 240  1998 ליטר חשמל/בנזין          50,000     1  אוטומטי   אפור פלדה
#
#     original_onership next_test_in annual_licensing_fee   price
# 0              ליסינג     ‏1,424 ₪                21999       0
# 1               פרטית     2 חודשים             ‏1,424 ₪   59900
# 2               פרטית     1 חודשים             ‏2,019 ₪   74900
# 3               פרטית     1 חודשים             ‏2,019 ₪   74900
# 4               פרטית     3 חודשים             ‏1,962 ₪  135000
# ..                ...          ...                  ...     ...
# 236             פרטית     8 חודשים             ‏2,563 ₪  199500
# 237             פרטית     6 חודשים             ‏1,102 ₪   64900
# 238             פרטית     6 חודשים             ‏1,102 ₪   66900
# 239             פרטית    11 חודשים             ‏1,102 ₪   68500
# 240        ייבוא אישי     5 חודשים             ‏4,731 ₪  330000
#
# [241 rows x 12 columns]

# %%
#cars.to_csv('cars_data.csv'  )

# %%
cars = pd.read_csv(r'C:\Users\avoav\Introduction to Data Science\Project סמסטר א\project-semester-a\cars_data.csv')
cars = cars.drop(columns=['Unnamed: 0' ]  )
cars
# Out:
#     CompanyName                                    version  year  \
# 0          פורד                           פורד פוקוס TREND  2013
# 1         ניסאן                       ניסאן ג'וק TEKNA P.D  2015
# 2        סובארו                      סובארו XV 2.0 PREMIUM  2016
# 3        סובארו                      סובארו XV 2.0 PREMIUM  2016
# 4         מרצדס                מרצדס CLA קלאס CLA200 URBAN  2015
# ..          ...                                        ...   ...
# 236      ב.מ.וו    ב.מ.וו סדרה 3 330E IPERFORMAN EXCLUSIVE  2018
# 237         קיה                              קיה פיקנטו LX  2017
# 238      שברולט                            שברולט ספארק LT  2016
# 239      יונדאי                           יונדאי I10 PRIME  2019
# 240      ב.מ.וו  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019
#
#                    engine current_mileage  hand  gearBox       color  \
# 0         1596 ליטר בנזין         183,000     2  אוטומטי        אפור
# 1         1598 ליטר בנזין          75,000     2  אוטומטי        אפור
# 2         1995 ליטר בנזין         179,000     1  אוטומטי  תכלת מטאלי
# 3         1995 ליטר בנזין         179,000     1  אוטומטי  תכלת מטאלי
# 4         1595 ליטר בנזין          66,000     2  אוטומטי         לבן
# ..                    ...             ...   ...      ...         ...
# 236  1998 ליטר חשמל/בנזין          58,000     1  אוטומטי         לבן
# 237       1248 ליטר בנזין          53,229     2  אוטומטי  כסוף מטאלי
# 238       1399 ליטר בנזין          59,582     2  אוטומטי         לבן
# 239       1248 ליטר בנזין          24,500     1  אוטומטי        שחור
# 240  1998 ליטר חשמל/בנזין          50,000     1  אוטומטי   אפור פלדה
#
#     original_onership next_test_in annual_licensing_fee   price
# 0              ליסינג     ‏1,424 ₪                21999       0
# 1               פרטית     2 חודשים             ‏1,424 ₪   59900
# 2               פרטית     1 חודשים             ‏2,019 ₪   74900
# 3               פרטית     1 חודשים             ‏2,019 ₪   74900
# 4               פרטית     3 חודשים             ‏1,962 ₪  135000
# ..                ...          ...                  ...     ...
# 236             פרטית     8 חודשים             ‏2,563 ₪  199500
# 237             פרטית     6 חודשים             ‏1,102 ₪   64900
# 238             פרטית     6 חודשים             ‏1,102 ₪   66900
# 239             פרטית    11 חודשים             ‏1,102 ₪   68500
# 240        ייבוא אישי     5 חודשים             ‏4,731 ₪  330000
#
# [241 rows x 12 columns]

# %%
#change the "gearBox" column to number:
cars.replace({'gearBox': 'ידני' } ,2 , inplace = True)

cars.replace({'gearBox': 'אוטומטי' } , 1 , inplace = True)
    
#cars.drop(columns=['index' , 'index.1' , 'index.1.1']  )

# %%
#change the "next_test_in" column to number:
cars['next_test_in'] = cars['next_test_in'].apply(lambda x : x.split(' ')[0])
cars
# Out:
#     CompanyName                                    version  year  \
# 0        nissan                       ניסאן ג'וק TEKNA P.D  2015
# 1        nissan                       ניסאן ג'וק TEKNA P.D  2015
# 2        nissan                       ניסאן ג'וק TEKNA P.D  2015
# 3        nissan                       ניסאן ג'וק TEKNA P.D  2015
# 4        nissan                       ניסאן ג'וק TEKNA P.D  2015
# ..          ...                                        ...   ...
# 299        audi                                   אאודי Q2  2018
# 300     hyundai                        יונדאי קונה SUPREME  2018
# 301   chevrolet                            שברולט ספארק LT  2016
# 302     hyundai                           יונדאי I10 PRIME  2019
# 303         bmw  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019
#
#                    engine current_mileage  hand  gearBox      color  \
# 0         1598 ליטר בנזין          75,000     2        1       אפור
# 1         1598 ליטר בנזין          75,000     2        1       אפור
# 2         1598 ליטר בנזין          99,000     2        1  שחור מטלי
# 3         1598 ליטר בנזין          99,000     2        1  שחור מטלי
# 4         1598 ליטר בנזין          75,000     2        1       אפור
# ..                    ...             ...   ...      ...        ...
# 299       1395 ליטר בנזין         139,804     1        1        לבן
# 300       1591 ליטר בנזין          42,248     1        1        לבן
# 301       1399 ליטר בנזין          59,582     2        1        לבן
# 302       1248 ליטר בנזין          24,500     1        1       שחור
# 303  1998 ליטר חשמל/בנזין          50,000     1        1  אפור פלדה
#
#     original_onership next_test_in annual_licensing_fee  price
# 0               פרטית            2             ‏1,424 ₪    0.0
# 1               פרטית            2             ‏1,424 ₪    0.0
# 2               פרטית            3             ‏1,424 ₪    0.0
# 3               פרטית            3             ‏1,424 ₪    0.0
# 4               פרטית            2             ‏1,424 ₪    0.0
# ..                ...          ...                  ...    ...
# 299             פרטית           11             ‏2,019 ₪    0.0
# 300             פרטית            2             ‏1,604 ₪    0.0
# 301             פרטית            6             ‏1,102 ₪    0.0
# 302             פרטית           11             ‏1,102 ₪    0.0
# 303        ייבוא אישי            5             ‏4,731 ₪    0.0
#
# [304 rows x 12 columns]

# %%
cars_fewColumns = cars.iloc[: , [0,2, 4 , 5 ,6  ,7, 9 ,10, 11]]
#it's getting close to something we can work with...
cars_fewColumns
# Out:
#     CompanyName  year current_mileage  hand  gearBox       color next_test_in  \
# 0          פורד  2013         183,000     2        1        אפור     ‏1,424 ₪
# 1         ניסאן  2015          75,000     2        1        אפור     2 חודשים
# 2        סובארו  2016         179,000     1        1  תכלת מטאלי     1 חודשים
# 3        סובארו  2016         179,000     1        1  תכלת מטאלי     1 חודשים
# 4         מרצדס  2015          66,000     2        1         לבן     3 חודשים
# ..          ...   ...             ...   ...      ...         ...          ...
# 236      ב.מ.וו  2018          58,000     1        1         לבן     8 חודשים
# 237         קיה  2017          53,229     2        1  כסוף מטאלי     6 חודשים
# 238      שברולט  2016          59,582     2        1         לבן     6 חודשים
# 239      יונדאי  2019          24,500     1        1        שחור    11 חודשים
# 240      ב.מ.וו  2019          50,000     1        1   אפור פלדה     5 חודשים
#
#     annual_licensing_fee   price
# 0                  21999       0
# 1               ‏1,424 ₪   59900
# 2               ‏2,019 ₪   74900
# 3               ‏2,019 ₪   74900
# 4               ‏1,962 ₪  135000
# ..                   ...     ...
# 236             ‏2,563 ₪  199500
# 237             ‏1,102 ₪   64900
# 238             ‏1,102 ₪   66900
# 239             ‏1,102 ₪   68500
# 240             ‏4,731 ₪  330000
#
# [241 rows x 9 columns]

# %%
# Out:
# 37000

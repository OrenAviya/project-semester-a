# %%
import time
import numpy as np
import pandas as pd
import requests 
from bs4 import BeautifulSoup

# %%
#import sklaern

v_indexes = [ 0 ]
eleven_columns = ['version' , 'year' , 'engine' , 'current_mileage' , 'hand' , 'gearBox' , 'color' , 'original_onership' , 'next_test_in' , 'annual_licensing_fee' , 'price']
ten_columns = ['version' , 'year' , 'engine' , 'current_mileage' , 'hand' , 'gearBox' , 'color' , 'original_onership' ,'next_test_in',  'annual_licensing_fee' ]
cars = pd.read_csv(r"C:\Users\avoav\Introduction to Data Science\Project סמסטר א\project-semester-a\DataFrame_cars_urls\cars_urls_data.csv" ,index_col=0 )

cars = cars.rename( columns = {'0' : 'url'} )
df_Det = pd.DataFrame( columns= eleven_columns)
for url in cars['url']:
    one_car = requests.get(url)
    soup = BeautifulSoup(one_car.content , 'html.parser')
    
    Det = soup.select('td' , class_='MuiTableCell-root MuiTableCell-body MuiTableCell-alignLeft MuiTableCell-paddingNone')
    
    det_array = []
# how to choose only the second td each time?
    for i in range(len(Det)):
        if (i%2 != 0):
            det_array.append(Det[i].get_text())
            if (Det[i].get_text() == None):
                det_array.append(None)
    if (len(det_array) ==10):
        df_det_array = pd.DataFrame(np.array([det_array]) , columns = ten_columns  ) 
    
    #how to append data with different number of columns 
    df_Det = pd.concat([df_Det ,df_det_array] , ignore_index = True , sort = False).fillna(0)
    print(df_Det)
print(df_Det)
# Out:
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
#
#   current_mileage hand  gearBox      color original_onership next_test_in  \
# 0          50,000    1  אוטומטי  אפור פלדה        ייבוא אישי     5 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪      0
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
#
#   current_mileage hand  gearBox      color original_onership next_test_in  \
# 0          50,000    1  אוטומטי  אפור פלדה        ייבוא אישי     5 חודשים
# 1          50,000    1  אוטומטי  אפור פלדה        ייבוא אישי     5 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪    0.0
# 1             ‏4,731 ₪    0.0
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
#
#   current_mileage hand  gearBox      color original_onership next_test_in  \
# 0          50,000    1  אוטומטי  אפור פלדה        ייבוא אישי     5 חודשים
# 1          50,000    1  אוטומטי  אפור פלדה        ייבוא אישי     5 חודשים
# 2          99,000    2  אוטומטי  שחור מטלי             פרטית     3 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪    0.0
# 1             ‏4,731 ₪    0.0
# 2             ‏1,424 ₪    0.0
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
#
#   current_mileage hand  gearBox      color original_onership next_test_in  \
# 0          50,000    1  אוטומטי  אפור פלדה        ייבוא אישי     5 חודשים
# 1          50,000    1  אוטומטי  אפור פלדה        ייבוא אישי     5 חודשים
# 2          99,000    2  אוטומטי  שחור מטלי             פרטית     3 חודשים
# 3          99,000    2  אוטומטי  שחור מטלי             פרטית     3 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪    0.0
# 1             ‏4,731 ₪    0.0
# 2             ‏1,424 ₪    0.0
# 3             ‏1,424 ₪    0.0
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
#
#   current_mileage hand  gearBox      color original_onership next_test_in  \
# 0          50,000    1  אוטומטי  אפור פלדה        ייבוא אישי     5 חודשים
# 1          50,000    1  אוטומטי  אפור פלדה        ייבוא אישי     5 חודשים
# 2          99,000    2  אוטומטי  שחור מטלי             פרטית     3 חודשים
# 3          99,000    2  אוטומטי  שחור מטלי             פרטית     3 חודשים
# 4          75,000    2  אוטומטי       אפור             פרטית     2 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪    0.0
# 1             ‏4,731 ₪    0.0
# 2             ‏1,424 ₪    0.0
# 3             ‏1,424 ₪    0.0
# 4             ‏1,424 ₪    0.0
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
#
#   current_mileage hand  gearBox       color original_onership next_test_in  \
# 0          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 1          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 2          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 3          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 4          75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 5         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪    0.0
# 1             ‏4,731 ₪    0.0
# 2             ‏1,424 ₪    0.0
# 3             ‏1,424 ₪    0.0
# 4             ‏1,424 ₪    0.0
# 5             ‏2,019 ₪    0.0
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
#
#   current_mileage hand  gearBox       color original_onership next_test_in  \
# 0          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 1          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 2          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 3          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 4          75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 5         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 6         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪    0.0
# 1             ‏4,731 ₪    0.0
# 2             ‏1,424 ₪    0.0
# 3             ‏1,424 ₪    0.0
# 4             ‏1,424 ₪    0.0
# 5             ‏2,019 ₪    0.0
# 6             ‏2,019 ₪    0.0
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
#
#   current_mileage hand  gearBox       color original_onership next_test_in  \
# 0          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 1          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 2          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 3          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 4          75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 5         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 6         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 7         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪    0.0
# 1             ‏4,731 ₪    0.0
# 2             ‏1,424 ₪    0.0
# 3             ‏1,424 ₪    0.0
# 4             ‏1,424 ₪    0.0
# 5             ‏2,019 ₪    0.0
# 6             ‏2,019 ₪    0.0
# 7             ‏2,019 ₪    0.0
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
#
#   current_mileage hand  gearBox       color original_onership next_test_in  \
# 0          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 1          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 2          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 3          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 4          75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 5         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 6         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 7         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 8         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪    0.0
# 1             ‏4,731 ₪    0.0
# 2             ‏1,424 ₪    0.0
# 3             ‏1,424 ₪    0.0
# 4             ‏1,424 ₪    0.0
# 5             ‏2,019 ₪    0.0
# 6             ‏2,019 ₪    0.0
# 7             ‏2,019 ₪    0.0
# 8             ‏2,019 ₪    0.0
#                                      version  year                engine  \
# 0  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                       ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                      סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
#
#   current_mileage hand  gearBox       color original_onership next_test_in  \
# 0          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 1          50,000    1  אוטומטי   אפור פלדה        ייבוא אישי     5 חודשים
# 2          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 3          99,000    2  אוטומטי   שחור מטלי             פרטית     3 חודשים
# 4          75,000    2  אוטומטי        אפור             פרטית     2 חודשים
# 5         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 6         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 7         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 8         179,000    1  אוטומטי  תכלת מטאלי             פרטית     1 חודשים
# 9          66,000    2  אוטומטי         לבן             פרטית     3 חודשים
#
#   annual_licensing_fee  price
# 0             ‏4,731 ₪    0.0
# 1             ‏4,731 ₪    0.0
# 2             ‏1,424 ₪    0.0
# 3             ‏1,424 ₪    0.0
# 4             ‏1,424 ₪    0.0
# 5             ‏2,019 ₪    0.0
# 6             ‏2,019 ₪    0.0
# 7             ‏2,019 ₪    0.0
# 8             ‏2,019 ₪    0.0
# 9             ‏1,962 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
# 13                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
# 13                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 14                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
# 14         261,000    3  אוטומטי             לבן             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
# 14     1 חודשים             ‏1,369 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
# 13                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 14                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 15                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
# 14         261,000    3  אוטומטי             לבן             פרטית
# 15         218,000    2  אוטומטי            שחור             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
# 14     1 חודשים             ‏1,369 ₪    0.0
# 15     3 חודשים             ‏1,508 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
# 13                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 14                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 15                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 16                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
# 14         261,000    3  אוטומטי             לבן             פרטית
# 15         218,000    2  אוטומטי            שחור             פרטית
# 16         218,000    2  אוטומטי            שחור             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
# 14     1 חודשים             ‏1,369 ₪    0.0
# 15     3 חודשים             ‏1,508 ₪    0.0
# 16     3 חודשים             ‏1,508 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
# 13                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 14                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 15                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 16                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 17                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
# 14         261,000    3  אוטומטי             לבן             פרטית
# 15         218,000    2  אוטומטי            שחור             פרטית
# 16         218,000    2  אוטומטי            שחור             פרטית
# 17         218,000    2  אוטומטי            שחור             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
# 14     1 חודשים             ‏1,369 ₪    0.0
# 15     3 חודשים             ‏1,508 ₪    0.0
# 16     3 חודשים             ‏1,508 ₪    0.0
# 17     3 חודשים             ‏1,508 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
# 13                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 14                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 15                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 16                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 17                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 18                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
# 14         261,000    3  אוטומטי             לבן             פרטית
# 15         218,000    2  אוטומטי            שחור             פרטית
# 16         218,000    2  אוטומטי            שחור             פרטית
# 17         218,000    2  אוטומטי            שחור             פרטית
# 18         135,000    4  אוטומטי            שחור             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
# 14     1 חודשים             ‏1,369 ₪    0.0
# 15     3 חודשים             ‏1,508 ₪    0.0
# 16     3 חודשים             ‏1,508 ₪    0.0
# 17     3 חודשים             ‏1,508 ₪    0.0
# 18     4 חודשים             ‏1,962 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
# 13                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 14                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 15                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 16                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 17                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 18                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 19                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
# 14         261,000    3  אוטומטי             לבן             פרטית
# 15         218,000    2  אוטומטי            שחור             פרטית
# 16         218,000    2  אוטומטי            שחור             פרטית
# 17         218,000    2  אוטומטי            שחור             פרטית
# 18         135,000    4  אוטומטי            שחור             פרטית
# 19         135,000    4  אוטומטי            שחור             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
# 14     1 חודשים             ‏1,369 ₪    0.0
# 15     3 חודשים             ‏1,508 ₪    0.0
# 16     3 חודשים             ‏1,508 ₪    0.0
# 17     3 חודשים             ‏1,508 ₪    0.0
# 18     4 חודשים             ‏1,962 ₪    0.0
# 19     4 חודשים             ‏1,962 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
# 13                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 14                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 15                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 16                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 17                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 18                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 19                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 20                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
# 14         261,000    3  אוטומטי             לבן             פרטית
# 15         218,000    2  אוטומטי            שחור             פרטית
# 16         218,000    2  אוטומטי            שחור             פרטית
# 17         218,000    2  אוטומטי            שחור             פרטית
# 18         135,000    4  אוטומטי            שחור             פרטית
# 19         135,000    4  אוטומטי            שחור             פרטית
# 20         135,000    4  אוטומטי            שחור             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
# 14     1 חודשים             ‏1,369 ₪    0.0
# 15     3 חודשים             ‏1,508 ₪    0.0
# ...
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
# 14         261,000    3  אוטומטי             לבן             פרטית
# 15         218,000    2  אוטומטי            שחור             פרטית
# 16         218,000    2  אוטומטי            שחור             פרטית
# 17         218,000    2  אוטומטי            שחור             פרטית
# 18         135,000    4  אוטומטי            שחור             פרטית
# 19         135,000    4  אוטומטי            שחור             פרטית
# 20         135,000    4  אוטומטי            שחור             פרטית
# 21         135,000    4  אוטומטי            שחור             פרטית
# 22         169,000    3  אוטומטי             כסף            ליסינג
# 23         169,000    3  אוטומטי             כסף            ליסינג
# 24         169,000    3  אוטומטי             כסף            ליסינג
# 25         149,000    3  אוטומטי            אפור            ליסינג
# 26          39,000    2  אוטומטי             לבן             פרטית
# 27         164,000    1  אוטומטי  אפור בהיר מטלי             פרטית
# 28         164,000    1  אוטומטי  אפור בהיר מטלי             פרטית
# 29         164,000    1  אוטומטי  אפור בהיר מטלי             פרטית
# 30         205,000    3  אוטומטי             לבן            ליסינג
# 31         205,000    3  אוטומטי             לבן            ליסינג
# 32         205,000    3  אוטומטי             לבן            ליסינג
# 33          80,000    5  אוטומטי       שחור מטלי             פרטית
# 34          80,000    5  אוטומטי       שחור מטלי             פרטית
# 35          80,000    5  אוטומטי       שחור מטלי             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
# 14     1 חודשים             ‏1,369 ₪    0.0
# 15     3 חודשים             ‏1,508 ₪    0.0
# 16     3 חודשים             ‏1,508 ₪    0.0
# 17     3 חודשים             ‏1,508 ₪    0.0
# 18     4 חודשים             ‏1,962 ₪    0.0
# 19     4 חודשים             ‏1,962 ₪    0.0
# 20     4 חודשים             ‏1,962 ₪    0.0
# 21     4 חודשים             ‏1,962 ₪    0.0
# 22    10 חודשים             ‏1,074 ₪    0.0
# 23    10 חודשים             ‏1,074 ₪    0.0
# 24    10 חודשים             ‏1,074 ₪    0.0
# 25     3 חודשים             ‏1,693 ₪    0.0
# 26     4 חודשים             ‏2,019 ₪    0.0
# 27     1 חודשים             ‏1,604 ₪    0.0
# 28     1 חודשים             ‏1,604 ₪    0.0
# 29     1 חודשים             ‏1,604 ₪    0.0
# 30     1 חודשים             ‏1,074 ₪    0.0
# 31     1 חודשים             ‏1,074 ₪    0.0
# 32     1 חודשים             ‏1,074 ₪    0.0
# 33     3 חודשים             ‏3,357 ₪    0.0
# 34     3 חודשים             ‏3,357 ₪    0.0
# 35     3 חודשים             ‏3,357 ₪    0.0
#                                       version  year                engine  \
# 0   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 1   ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019  1998 ליטר חשמל/בנזין
# 2                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 3                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 4                        ניסאן ג'וק TEKNA P.D  2015       1598 ליטר בנזין
# 5                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 6                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 7                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 8                       סובארו XV 2.0 PREMIUM  2016       1995 ליטר בנזין
# 9                 מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 10                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 11                     סיאט לאון LE CPOPA PLU  2012       1789 ליטר בנזין
# 12                         סיטרואן C4 COMFORT  2011       1598 ליטר בנזין
# 13                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 14                       טויוטה אוונסיס GLI-S  2006       1998 ליטר בנזין
# 15                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 16                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 17                  ג'יפ גראנד צ'ירוקי LAREDO  2011       3604 ליטר בנזין
# 18                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 19                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 20                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 21                מרצדס CLA קלאס CLA200 URBAN  2015       1595 ליטר בנזין
# 22                            יונדאי אקסנט GL  2010       1399 ליטר בנזין
# 23                            יונדאי אקסנט GL  2010       1399 ליטר בנזין
# 24                            יונדאי אקסנט GL  2010       1399 ליטר בנזין
# 25                       מאזדה CX-5 EXECUTIVE  2013       1998 ליטר בנזין
# 26                אלפא רומיאו ג'וליטה TURISMO  2016       1368 ליטר בנזין
# 27                     טויוטה אוריס HYBRID TS  2016       1798 ליטר בנזין
# 28                     טויוטה אוריס HYBRID TS  2016       1798 ליטר בנזין
# 29                     טויוטה אוריס HYBRID TS  2016       1798 ליטר בנזין
# 30                          דייהטסו סיריון CX  2010       1298 ליטר בנזין
# 31                          דייהטסו סיריון CX  2010       1298 ליטר בנזין
# 32                          דייהטסו סיריון CX  2010       1298 ליטר בנזין
# 33                   פורשה מקאן S ORCHID PACK  2016       2997 ליטר בנזין
# 34                   פורשה מקאן S ORCHID PACK  2016       2997 ליטר בנזין
# 35                   פורשה מקאן S ORCHID PACK  2016       2997 ליטר בנזין
# 36                      מרצדס C קלאס C250 AMG  2015       1991 ליטר בנזין
#
#    current_mileage hand  gearBox           color original_onership  \
# 0           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 1           50,000    1  אוטומטי       אפור פלדה        ייבוא אישי
# 2           99,000    2  אוטומטי       שחור מטלי             פרטית
# 3           99,000    2  אוטומטי       שחור מטלי             פרטית
# 4           75,000    2  אוטומטי            אפור             פרטית
# 5          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 6          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 7          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 8          179,000    1  אוטומטי      תכלת מטאלי             פרטית
# 9           66,000    2  אוטומטי             לבן             פרטית
# 10         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 11         135,000    3  אוטומטי  אפור בהיר מטלי             פרטית
# 12         187,000    2  אוטומטי            שחור            ליסינג
# 13         261,000    3  אוטומטי             לבן             פרטית
# 14         261,000    3  אוטומטי             לבן             פרטית
# 15         218,000    2  אוטומטי            שחור             פרטית
# 16         218,000    2  אוטומטי            שחור             פרטית
# 17         218,000    2  אוטומטי            שחור             פרטית
# 18         135,000    4  אוטומטי            שחור             פרטית
# 19         135,000    4  אוטומטי            שחור             פרטית
# 20         135,000    4  אוטומטי            שחור             פרטית
# 21         135,000    4  אוטומטי            שחור             פרטית
# 22         169,000    3  אוטומטי             כסף            ליסינג
# 23         169,000    3  אוטומטי             כסף            ליסינג
# 24         169,000    3  אוטומטי             כסף            ליסינג
# 25         149,000    3  אוטומטי            אפור            ליסינג
# 26          39,000    2  אוטומטי             לבן             פרטית
# 27         164,000    1  אוטומטי  אפור בהיר מטלי             פרטית
# 28         164,000    1  אוטומטי  אפור בהיר מטלי             פרטית
# 29         164,000    1  אוטומטי  אפור בהיר מטלי             פרטית
# 30         205,000    3  אוטומטי             לבן            ליסינג
# 31         205,000    3  אוטומטי             לבן            ליסינג
# 32         205,000    3  אוטומטי             לבן            ליסינג
# 33          80,000    5  אוטומטי       שחור מטלי             פרטית
# 34          80,000    5  אוטומטי       שחור מטלי             פרטית
# 35          80,000    5  אוטומטי       שחור מטלי             פרטית
# 36          85,000    4  אוטומטי             לבן             פרטית
#
#    next_test_in annual_licensing_fee  price
# 0      5 חודשים             ‏4,731 ₪    0.0
# 1      5 חודשים             ‏4,731 ₪    0.0
# 2      3 חודשים             ‏1,424 ₪    0.0
# 3      3 חודשים             ‏1,424 ₪    0.0
# 4      2 חודשים             ‏1,424 ₪    0.0
# 5      1 חודשים             ‏2,019 ₪    0.0
# 6      1 חודשים             ‏2,019 ₪    0.0
# 7      1 חודשים             ‏2,019 ₪    0.0
# 8      1 חודשים             ‏2,019 ₪    0.0
# 9      3 חודשים             ‏1,962 ₪    0.0
# 10     8 חודשים             ‏1,584 ₪    0.0
# 11     8 חודשים             ‏1,584 ₪    0.0
# 12     3 חודשים             ‏1,262 ₪    0.0
# 13     1 חודשים             ‏1,369 ₪    0.0
# 14     1 חודשים             ‏1,369 ₪    0.0
# 15     3 חודשים             ‏1,508 ₪    0.0
# 16     3 חודשים             ‏1,508 ₪    0.0
# 17     3 חודשים             ‏1,508 ₪    0.0
# 18     4 חודשים             ‏1,962 ₪    0.0
# 19     4 חודשים             ‏1,962 ₪    0.0
# 20     4 חודשים             ‏1,962 ₪    0.0
# 21     4 חודשים             ‏1,962 ₪    0.0
# 22    10 חודשים             ‏1,074 ₪    0.0
# 23    10 חודשים             ‏1,074 ₪    0.0
# 24    10 חודשים             ‏1,074 ₪    0.0
# 25     3 חודשים             ‏1,693 ₪    0.0
# 26     4 חודשים             ‏2,019 ₪    0.0
# 27     1 חודשים             ‏1,604 ₪    0.0
# 28     1 חודשים             ‏1,604 ₪    0.0
# 29     1 חודשים             ‏1,604 ₪    0.0
# 30     1 חודשים             ‏1,074 ₪    0.0
# 31     1 חודשים             ‏1,074 ₪    0.0
# 32     1 חודשים             ‏1,074 ₪    0.0
# 33     3 חודשים             ‏3,357 ₪    0.0
# 34     3 חודשים             ‏3,357 ₪    0.0
# 35     3 חודשים             ‏3,357 ₪    0.0
# 36     4 חודשים             ‏2,397 ₪    0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-828f0a9fd7b3> in <module>
#      14 df_Det = pd.DataFrame( columns= eleven_columns)
#      15 for url in cars['url']:
# ---> 16     one_car = requests.get(url)
#      17     soup = BeautifulSoup(one_car.content , 'html.parser')
#      18
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df_Det.to_csv('cars_data.csv' , index_label='index' )

# %%
cars = pd.read_csv(r'C:\Users\avoav\Introduction to Data Science\Project סמסטר א\project-semester-a\cars_data.csv')

# %%
cars.version.unique()
#we saw here that we need to split the "version" column to two columns : "CompanyName" and "version":
CompanyName = cars['version'].apply(lambda x : x.split(' ')[0])
cars.insert(1,"CompanyName",CompanyName)

# %%
cars
# Out:
#      index CompanyName                                    version  year  \
# 0        0       ניסאן                       ניסאן ג'וק TEKNA P.D  2015
# 1        1       ניסאן                       ניסאן ג'וק TEKNA P.D  2015
# 2        2       ניסאן                       ניסאן ג'וק TEKNA P.D  2015
# 3        3       ניסאן                       ניסאן ג'וק TEKNA P.D  2015
# 4        4       ניסאן                       ניסאן ג'וק TEKNA P.D  2015
# ..     ...         ...                                        ...   ...
# 299    299       אאודי                                   אאודי Q2  2018
# 300    300      יונדאי                        יונדאי קונה SUPREME  2018
# 301    301      שברולט                            שברולט ספארק LT  2016
# 302    302      יונדאי                           יונדאי I10 PRIME  2019
# 303    303      ב.מ.וו  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE  2019
#
#                    engine current_mileage  hand  gearBox      color  \
# 0         1598 ליטר בנזין          75,000     2  אוטומטי       אפור
# 1         1598 ליטר בנזין          75,000     2  אוטומטי       אפור
# 2         1598 ליטר בנזין          99,000     2  אוטומטי  שחור מטלי
# 3         1598 ליטר בנזין          99,000     2  אוטומטי  שחור מטלי
# 4         1598 ליטר בנזין          75,000     2  אוטומטי       אפור
# ..                    ...             ...   ...      ...        ...
# 299       1395 ליטר בנזין         139,804     1  אוטומטי        לבן
# 300       1591 ליטר בנזין          42,248     1  אוטומטי        לבן
# 301       1399 ליטר בנזין          59,582     2  אוטומטי        לבן
# 302       1248 ליטר בנזין          24,500     1  אוטומטי       שחור
# 303  1998 ליטר חשמל/בנזין          50,000     1  אוטומטי  אפור פלדה
#
#     original_onership next_test_in annual_licensing_fee  price
# 0               פרטית     2 חודשים             ‏1,424 ₪    0.0
# 1               פרטית     2 חודשים             ‏1,424 ₪    0.0
# 2               פרטית     3 חודשים             ‏1,424 ₪    0.0
# 3               פרטית     3 חודשים             ‏1,424 ₪    0.0
# 4               פרטית     2 חודשים             ‏1,424 ₪    0.0
# ..                ...          ...                  ...    ...
# 299             פרטית    11 חודשים             ‏2,019 ₪    0.0
# 300             פרטית     2 חודשים             ‏1,604 ₪    0.0
# 301             פרטית     6 חודשים             ‏1,102 ₪    0.0
# 302             פרטית    11 חודשים             ‏1,102 ₪    0.0
# 303        ייבוא אישי     5 חודשים             ‏4,731 ₪    0.0
#
# [304 rows x 13 columns]

# %%
car_names = cars.CompanyName.unique()
car_names
# Out:
# array(['ניסאן', 'סובארו', 'מרצדס', 'סיאט', 'סיטרואן', 'טויוטה', "ג'יפ",
#        'מאזדה', 'קיה', 'יונדאי', 'אלפא', 'דייהטסו', 'פורשה', 'פיאט',
#        'פורד', 'סוזוקי', "דאצ'יה", 'ב.מ.וו', "פיג'ו", 'מיצובישי',
#        'פולקסווגן', 'רנו', 'הונדה', 'אאודי', 'סקודה', 'מיני', 'אינפיניטי',
#        'לנד', 'MG', 'אופל', 'שברולט'], dtype=object)

# %%
#there is some names we want to set right:
# לנד == לנד רובר
# אלפא = אלפא רומיאו
#we also need to change all names to english so we do that together:

car_names = cars.CompanyName.unique()
i=0
#for item in car_names:
lambda item :
    if (item == "אלפא"): 
        car_names[i] = 'alfa-romeo'  
    elif (item =='ניסאן'): 
        car_names[i] = 'nissan'
    elif (item == "מאזדה"): 
        car_names[i] = 'mazda'
    elif (item == "סובארו"): 
        car_names[i] = 'subaru'
    elif (item == "מרצדס"): 
        car_names[i] = 'mercedes'
    elif (item == "סיאט"): 
        car_names[i] = 'sia'   
    elif (item == "סיטרואן"): 
        car_names[i] = 'citroen'   
    elif (item == "טויוטה"): 
        car_names[i] = 'toyota'   
    elif (item =="ג'יפ"): 
        car_names[i] = 'jeep'   
    elif (item == "קיה"): 
        car_names[i] = 'kia'   
    elif (item == "יונדאי"): 
        car_names[i] = 'hyundai'   
    elif (item == "דייהטסו"): 
        car_names[i] = 'daihatsu'   
    elif (item == "פורשה"): 
        car_names[i] = 'porsche'   
    elif (item == "פיאט"): 
        car_names[i] = 'fiat'   
    elif (item == "פורד"): 
        car_names[i] = 'ford'   
    elif (item == "סוזוקי"): 
        car_names[i] = 'suzuki'   
    elif (item == "דאצ'יה"): 
        car_names[i] = 'dacia'   
    elif (item == "ב.מ.וו"): 
        car_names[i] = 'bmw'   
    elif (item == "פיג'ו"): 
        car_names[i] = 'peugeot'   
    elif (item == "מיצובישי"): 
        car_names[i] = 'mitsubishi'   
    elif (item == "פולקסווגן"): 
        car_names[i] = 'volkswagen'   
    elif (item == "רנו"): 
        car_names[i] = 'reno' 
    elif (item == "הונדה"): 
        car_names[i] = 'honda' 
    elif (item == "אאודי"): 
        car_names[i] = 'audi' 
    elif (item == "סקודה"): 
        car_names[i] = 'skoda' 
    elif (item == "מיני"): 
        car_names[i] = 'mini' 
    elif (item == "אינפיניטי"): 
        car_names[i] = 'infinity'
    elif (item == "לנד"): 
        car_names[i] = 'landrover' 
    elif (item == "שברולט"): 
        car_names[i] = 'chevrolet'
    elif (item == "אופל"): 
        car_names[i] = 'opel'
    elif (item == "MG"): 
        car_names[i] = 'MG'
    elif (item == "טסלה"): 
        car_names[i] = 'tesla'
    elif (item == "'דודג"): 
        car_names[i] = 'dodge'
    elif (item == "ביואיק"): 
        car_names[i] = 'buick'
    elif (item == "יגואר"): 
        car_names[i] = 'jaguar'   
    elif (item == "לקסוס"): 
        car_names[i] = 'lexus' 
    elif (item == "סמארט"): 
        car_names[i] = 'smart'
    elif (item == "סאנגיונג"): 
        car_names[i] = 'sangiang'
    elif (item == "קאדילק"): 
        car_names[i] = 'cadillac'
    elif (item == "קופרה"): 
        car_names[i] = 'cupra'   
    elif (item == "קרייזלר"): 
        car_names[i] = 'chrysler'
    elif (item == "מזארטי"): 
        car_names[i] = 'maserati' 
    elif (item == "וולבו"): 
        car_names[i] = 'volvo'
    elif (item == "איסוזו"): 
        car_names[i] = 'isuzu'
    elif (item == "GMC"): 
        car_names[i] = 'gmc'   
    else:
        item = "mazda" # one of the popular cars... 
    i= i+1   


print(car_names)
# Out:
#   File "<ipython-input-96-3f133cee66eb>", line 9
#     lambda item :
#                  ^
# SyntaxError: invalid syntax

# %%
# now, we want to change the column "CompanyName" :
def item_to_E (item):
    if (item == "אלפא"): 
        item = 'alfa-romeo'  
    elif (item =='ניסאן'): 
        item = 'nissan'
    elif (item == "מאזדה"): 
        item = 'mazda'
    elif (item == "סובארו"): 
        item = 'subaru'
    elif (item == "מרצדס"): 
        item = 'mercedes'
    elif (item == "סיאט"): 
        item = 'sia'   
    elif (item == "סיטרואן"): 
        item = 'citroen'   
    elif (item == "טויוטה"): 
        item = 'toyota'   
    elif (item =="ג'יפ"): 
        item = 'jeep'   
    elif (item == "קיה"): 
        item = 'kia'   
    elif (item == "יונדאי"): 
        item = 'hyundai'   
    elif (item == "דייהטסו"): 
        item = 'daihatsu'   
    elif (item == "פורשה"): 
        item = 'porsche'   
    elif (item == "פיאט"): 
        item = 'fiat'   
    elif (item == "פורד"): 
        item = 'ford'   
    elif (item == "סוזוקי"): 
        item = 'suzuki'   
    elif (item == "דאצ'יה"): 
        item = 'dacia'   
    elif (item == "ב.מ.וו"): 
        item = 'bmw'   
    elif (item == "פיג'ו"): 
        item = 'peugeot'   
    elif (item == "מיצובישי"): 
        item = 'mitsubishi'   
    elif (item == "פולקסווגן"): 
        item = 'volkswagen'   
    elif (item == "רנו"): 
        item = 'reno' 
    elif (item == "הונדה"): 
        item = 'honda' 
    elif (item == "אאודי"): 
        item = 'audi' 
    elif (item == "סקודה"): 
        item = 'skoda' 
    elif (item == "מיני"): 
        item = 'mini' 
    elif (item == "אינפיניטי"): 
        item = 'infinity'
    elif (item == "לנד"): 
        item = 'landrover' 
    elif (item == "שברולט"): 
        item = 'chevrolet'
    elif (item == "אופל"): 
        item = 'opel'
    elif (item == "MG"): 
        item = 'MG'
    elif (item == "טסלה"): 
        item = 'tesla'
    elif (item == "'דודג"): 
        item = 'dodge'
    elif (item == "ביואיק"): 
        item = 'buick'
    elif (item == "יגואר"): 
        item = 'jaguar'   
    elif (item == "לקסוס"): 
        item = 'lexus' 
    elif (item == "סמארט"): 
        item = 'smart'
    elif (item == "סאנגיונג"): 
        item = 'sangiang'
    elif (item == "קאדילק"): 
        item = 'cadillac'
    elif (item == "קופרה"): 
        item = 'cupra'   
    elif (item == "קרייזלר"): 
        item = 'chrysler'
    elif (item == "מזארטי"): 
        item = 'maserati' 
    elif (item == "וולבו"): 
        item = 'volvo'
    elif (item == "איסוזו"): 
        item = 'isuzu'
    elif (item == "GMC"): 
        item = 'gmc'
    else:
        item = "mazda" # one of the popular cars... 
    return item

for i in range (len(cars['CompanyName'])):
    cars['CompanyName'][i] = item_to_E(cars['CompanyName'][i])
# Out:
# <ipython-input-97-640d0f46d514>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars['CompanyName'][i] = item_to_E(cars['CompanyName'][i])

# %%
cars['CompanyName']
# Out:
# 0         nissan
# 1         nissan
# 2         nissan
# 3         nissan
# 4         nissan
#          ...
# 299         audi
# 300      hyundai
# 301    chevrolet
# 302      hyundai
# 303          bmw
# Name: CompanyName, Length: 304, dtype: object

# %%
cars.to_csv('cars_data.csv' , index_label='index' )

# %%
cars = pd.read_csv(r'C:\Users\avoav\Introduction to Data Science\Project סמסטר א\project-semester-a\cars_data.csv')
cars
# Out:
#      index  index.1 CompanyName                                    version  \
# 0        0        0      nissan                       ניסאן ג'וק TEKNA P.D
# 1        1        1      nissan                       ניסאן ג'וק TEKNA P.D
# 2        2        2      nissan                       ניסאן ג'וק TEKNA P.D
# 3        3        3      nissan                       ניסאן ג'וק TEKNA P.D
# 4        4        4      nissan                       ניסאן ג'וק TEKNA P.D
# ..     ...      ...         ...                                        ...
# 299    299      299        audi                                   אאודי Q2
# 300    300      300     hyundai                        יונדאי קונה SUPREME
# 301    301      301   chevrolet                            שברולט ספארק LT
# 302    302      302     hyundai                           יונדאי I10 PRIME
# 303    303      303         bmw  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE
#
#      year                engine current_mileage  hand  gearBox      color  \
# 0    2015       1598 ליטר בנזין          75,000     2  אוטומטי       אפור
# 1    2015       1598 ליטר בנזין          75,000     2  אוטומטי       אפור
# 2    2015       1598 ליטר בנזין          99,000     2  אוטומטי  שחור מטלי
# 3    2015       1598 ליטר בנזין          99,000     2  אוטומטי  שחור מטלי
# 4    2015       1598 ליטר בנזין          75,000     2  אוטומטי       אפור
# ..    ...                   ...             ...   ...      ...        ...
# 299  2018       1395 ליטר בנזין         139,804     1  אוטומטי        לבן
# 300  2018       1591 ליטר בנזין          42,248     1  אוטומטי        לבן
# 301  2016       1399 ליטר בנזין          59,582     2  אוטומטי        לבן
# 302  2019       1248 ליטר בנזין          24,500     1  אוטומטי       שחור
# 303  2019  1998 ליטר חשמל/בנזין          50,000     1  אוטומטי  אפור פלדה
#
#     original_onership next_test_in annual_licensing_fee  price
# 0               פרטית     2 חודשים             ‏1,424 ₪    0.0
# 1               פרטית     2 חודשים             ‏1,424 ₪    0.0
# 2               פרטית     3 חודשים             ‏1,424 ₪    0.0
# 3               פרטית     3 חודשים             ‏1,424 ₪    0.0
# 4               פרטית     2 חודשים             ‏1,424 ₪    0.0
# ..                ...          ...                  ...    ...
# 299             פרטית    11 חודשים             ‏2,019 ₪    0.0
# 300             פרטית     2 חודשים             ‏1,604 ₪    0.0
# 301             פרטית     6 חודשים             ‏1,102 ₪    0.0
# 302             פרטית    11 חודשים             ‏1,102 ₪    0.0
# 303        ייבוא אישי     5 חודשים             ‏4,731 ₪    0.0
#
# [304 rows x 14 columns]

# %%
#change the "gearBox" column to number:
i=0
for item in cars['gearBox']:
    if (item == 'אוטומטי'):
        cars['gearBox'][i] = 1
    if (item =='ידני'):
        cars['gearBox'][i] = 2
    i+=1
cars
# Out:
#      index  index.1 CompanyName                                    version  \
# 0        0        0      nissan                       ניסאן ג'וק TEKNA P.D
# 1        1        1      nissan                       ניסאן ג'וק TEKNA P.D
# 2        2        2      nissan                       ניסאן ג'וק TEKNA P.D
# 3        3        3      nissan                       ניסאן ג'וק TEKNA P.D
# 4        4        4      nissan                       ניסאן ג'וק TEKNA P.D
# ..     ...      ...         ...                                        ...
# 299    299      299        audi                                   אאודי Q2
# 300    300      300     hyundai                        יונדאי קונה SUPREME
# 301    301      301   chevrolet                            שברולט ספארק LT
# 302    302      302     hyundai                           יונדאי I10 PRIME
# 303    303      303         bmw  ב.מ.וו סדרה 5 530E iPERFORMANCE EXCLUSIVE
#
#      year                engine current_mileage  hand gearBox      color  \
# 0    2015       1598 ליטר בנזין          75,000     2       1       אפור
# 1    2015       1598 ליטר בנזין          75,000     2       1       אפור
# 2    2015       1598 ליטר בנזין          99,000     2       1  שחור מטלי
# 3    2015       1598 ליטר בנזין          99,000     2       1  שחור מטלי
# 4    2015       1598 ליטר בנזין          75,000     2       1       אפור
# ..    ...                   ...             ...   ...     ...        ...
# 299  2018       1395 ליטר בנזין         139,804     1       1        לבן
# 300  2018       1591 ליטר בנזין          42,248     1       1        לבן
# 301  2016       1399 ליטר בנזין          59,582     2       1        לבן
# 302  2019       1248 ליטר בנזין          24,500     1       1       שחור
# 303  2019  1998 ליטר חשמל/בנזין          50,000     1       1  אפור פלדה
#
#     original_onership next_test_in annual_licensing_fee  price
# 0               פרטית     2 חודשים             ‏1,424 ₪    0.0
# 1               פרטית     2 חודשים             ‏1,424 ₪    0.0
# 2               פרטית     3 חודשים             ‏1,424 ₪    0.0
# 3               פרטית     3 חודשים             ‏1,424 ₪    0.0
# 4               פרטית     2 חודשים             ‏1,424 ₪    0.0
# ..                ...          ...                  ...    ...
# 299             פרטית    11 חודשים             ‏2,019 ₪    0.0
# 300             פרטית     2 חודשים             ‏1,604 ₪    0.0
# 301             פרטית     6 חודשים             ‏1,102 ₪    0.0
# 302             פרטית    11 חודשים             ‏1,102 ₪    0.0
# 303        ייבוא אישי     5 חודשים             ‏4,731 ₪    0.0
#
# [304 rows x 14 columns]

# %%
#change the "next_test_in" column to number:
cars['next_test_in'] = cars['next_test_in'].apply(lambda x : x.split(' ')[0])

# %%
cars_fewColumns = cars.iloc[: , [1 ,2 , 4 , 6 ,7  ,8, 11 ,12]]
cars_fewColumns
#it's getting close to something we can work with...
# Out:
#      index.1 CompanyName  year current_mileage  hand gearBox next_test_in  \
# 0          0      nissan  2015          75,000     2       1            2
# 1          1      nissan  2015          75,000     2       1            2
# 2          2      nissan  2015          99,000     2       1            3
# 3          3      nissan  2015          99,000     2       1            3
# 4          4      nissan  2015          75,000     2       1            2
# ..       ...         ...   ...             ...   ...     ...          ...
# 299      299        audi  2018         139,804     1       1           11
# 300      300     hyundai  2018          42,248     1       1            2
# 301      301   chevrolet  2016          59,582     2       1            6
# 302      302     hyundai  2019          24,500     1       1           11
# 303      303         bmw  2019          50,000     1       1            5
#
#     annual_licensing_fee
# 0               ‏1,424 ₪
# 1               ‏1,424 ₪
# 2               ‏1,424 ₪
# 3               ‏1,424 ₪
# 4               ‏1,424 ₪
# ..                   ...
# 299             ‏2,019 ₪
# 300             ‏1,604 ₪
# 301             ‏1,102 ₪
# 302             ‏1,102 ₪
# 303             ‏4,731 ₪
#
# [304 rows x 8 columns]

# %%
# Out:
#   File "<ipython-input-115-8fc76c4cd8ca>", line 1
#     git add start_project_jup.ipynb
#         ^
# SyntaxError: invalid syntax

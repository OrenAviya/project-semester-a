# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

#Didn't import the SKL yet

# %%
wine = pd.read_csv(r'C:\Users\Alon\Desktop\קורסים\מדעי הנתונים\Kag\WineQT.csv', index_col='Id')

# %%
wine.reset_index(inplace=True)
wine.drop(columns='Id', inplace=True)

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1138     11.0        6
# 1139      9.5        6
# 1140     10.5        5
# 1141     11.2        6
# 1142     10.2        5
#
# [1143 rows x 12 columns]

# %% [markdown]
# # Exploring Data

# %% [markdown]
# ### Verify our data is cleaned and doesn't have nulls

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 107.3 KB

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### Explore the diffrence between values for each col

# %%
#a great way to see the radical values for each col.
COMPAR_NUM = 30

coloredData = sns.light_palette("brown", as_cmap=True)
wine.head(COMPAR_NUM).style.background_gradient(cmap=coloredData)
# Out:
# <style  type="text/css" >
# #T_cec7c_row0_col0,#T_cec7c_row4_col0,#T_cec7c_row5_col0{
#             background-color:  #d6a8a8;
#             color:  #000000;
#         }#T_cec7c_row0_col1,#T_cec7c_row4_col1{
#             background-color:  #bc6565;
#             color:  #000000;
#         }#T_cec7c_row0_col2,#T_cec7c_row1_col2,#T_cec7c_row3_col1,#T_cec7c_row4_col2,#T_cec7c_row5_col2,#T_cec7c_row6_col9,#T_cec7c_row7_col2,#T_cec7c_row7_col3,#T_cec7c_row7_col4,#T_cec7c_row10_col2,#T_cec7c_row10_col7,#T_cec7c_row11_col10,#T_cec7c_row12_col1,#T_cec7c_row13_col8,#T_cec7c_row19_col6,#T_cec7c_row20_col2,#T_cec7c_row21_col2,#T_cec7c_row24_col0,#T_cec7c_row25_col2,#T_cec7c_row26_col5,#T_cec7c_row27_col4,#T_cec7c_row29_col11{
#             background-color:  #f2f0f0;
#             color:  #000000;
#         }#T_cec7c_row0_col3,#T_cec7c_row3_col3,#T_cec7c_row4_col3,#T_cec7c_row15_col4,#T_cec7c_row20_col3{
#             background-color:  #e7d3d3;
#             color:  #000000;
#         }#T_cec7c_row0_col4,#T_cec7c_row4_col4,#T_cec7c_row18_col3,#T_cec7c_row26_col6,#T_cec7c_row29_col9{
#             background-color:  #efe8e8;
#             color:  #000000;
#         }#T_cec7c_row0_col5,#T_cec7c_row4_col5,#T_cec7c_row9_col0,#T_cec7c_row15_col6,#T_cec7c_row17_col2,#T_cec7c_row17_col3,#T_cec7c_row18_col5,#T_cec7c_row22_col0,#T_cec7c_row22_col3,#T_cec7c_row26_col2,#T_cec7c_row26_col3{
#             background-color:  #dfbebe;
#             color:  #000000;
#         }#T_cec7c_row0_col6,#T_cec7c_row4_col6{
#             background-color:  #e1c4c4;
#             color:  #000000;
#         }#T_cec7c_row0_col7,#T_cec7c_row4_col7,#T_cec7c_row5_col7,#T_cec7c_row28_col7{
#             background-color:  #b34f4f;
#             color:  #f1f1f1;
#         }#T_cec7c_row0_col8,#T_cec7c_row4_col8,#T_cec7c_row5_col8{
#             background-color:  #af4444;
#             color:  #f1f1f1;
#         }#T_cec7c_row0_col9,#T_cec7c_row4_col9,#T_cec7c_row5_col9,#T_cec7c_row18_col9{
#             background-color:  #ebdede;
#             color:  #000000;
#         }#T_cec7c_row0_col10,#T_cec7c_row4_col10,#T_cec7c_row5_col10,#T_cec7c_row6_col10,#T_cec7c_row11_col4,#T_cec7c_row11_col6,#T_cec7c_row16_col10,#T_cec7c_row20_col10{
#             background-color:  #e5cdcd;
#             color:  #000000;
#         }#T_cec7c_row0_col11,#T_cec7c_row1_col11,#T_cec7c_row2_col11,#T_cec7c_row4_col11,#T_cec7c_row5_col11,#T_cec7c_row6_col11,#T_cec7c_row9_col11,#T_cec7c_row10_col11,#T_cec7c_row11_col11,#T_cec7c_row14_col11,#T_cec7c_row15_col11,#T_cec7c_row16_col11,#T_cec7c_row18_col11,#T_cec7c_row19_col11,#T_cec7c_row20_col11,#T_cec7c_row22_col11,#T_cec7c_row23_col11,#T_cec7c_row24_col11,#T_cec7c_row28_col11{
#             background-color:  #d9aeae;
#             color:  #000000;
#         }#T_cec7c_row1_col0,#T_cec7c_row2_col0,#T_cec7c_row8_col0,#T_cec7c_row11_col0,#T_cec7c_row19_col2,#T_cec7c_row21_col0,#T_cec7c_row25_col0,#T_cec7c_row26_col0{
#             background-color:  #d19b9b;
#             color:  #000000;
#         }#T_cec7c_row1_col1,#T_cec7c_row3_col0,#T_cec7c_row3_col2,#T_cec7c_row7_col11,#T_cec7c_row8_col11,#T_cec7c_row10_col8,#T_cec7c_row11_col9,#T_cec7c_row12_col2,#T_cec7c_row12_col5,#T_cec7c_row12_col11,#T_cec7c_row13_col4,#T_cec7c_row23_col6,#T_cec7c_row25_col7,#T_cec7c_row26_col10,#T_cec7c_row27_col11,#T_cec7c_row28_col3{
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }#T_cec7c_row1_col3{
#             background-color:  #dbb5b5;
#             color:  #000000;
#         }#T_cec7c_row1_col4,#T_cec7c_row18_col6,#T_cec7c_row18_col10,#T_cec7c_row19_col9,#T_cec7c_row21_col9,#T_cec7c_row29_col10{
#             background-color:  #e9d9d9;
#             color:  #000000;
#         }#T_cec7c_row1_col5{
#             background-color:  #bd6767;
#             color:  #000000;
#         }#T_cec7c_row1_col6,#T_cec7c_row11_col1,#T_cec7c_row12_col0,#T_cec7c_row14_col2,#T_cec7c_row16_col0,#T_cec7c_row16_col6,#T_cec7c_row29_col1{
#             background-color:  #c88383;
#             color:  #000000;
#         }#T_cec7c_row1_col7,#T_cec7c_row8_col7,#T_cec7c_row16_col7,#T_cec7c_row17_col7,#T_cec7c_row27_col7{
#             background-color:  #c57d7d;
#             color:  #000000;
#         }#T_cec7c_row1_col8,#T_cec7c_row25_col10{
#             background-color:  #dcb6b6;
#             color:  #000000;
#         }#T_cec7c_row1_col9,#T_cec7c_row17_col1{
#             background-color:  #e3c9c8;
#             color:  #000000;
#         }#T_cec7c_row1_col10,#T_cec7c_row2_col10,#T_cec7c_row3_col10,#T_cec7c_row21_col10,#T_cec7c_row23_col10{
#             background-color:  #d29f9f;
#             color:  #000000;
#         }#T_cec7c_row2_col1{
#             background-color:  #b45252;
#             color:  #f1f1f1;
#         }#T_cec7c_row2_col2,#T_cec7c_row9_col9,#T_cec7c_row17_col4,#T_cec7c_row22_col9{
#             background-color:  #ede2e2;
#             color:  #000000;
#         }#T_cec7c_row2_col3,#T_cec7c_row14_col3,#T_cec7c_row16_col3,#T_cec7c_row23_col3{
#             background-color:  #e0c2c2;
#             color:  #000000;
#         }#T_cec7c_row2_col4,#T_cec7c_row7_col6,#T_cec7c_row8_col9,#T_cec7c_row12_col4{
#             background-color:  #ebdddd;
#             color:  #000000;
#         }#T_cec7c_row2_col5,#T_cec7c_row6_col5,#T_cec7c_row7_col5,#T_cec7c_row9_col5,#T_cec7c_row9_col7,#T_cec7c_row15_col2,#T_cec7c_row23_col5{
#             background-color:  #d5a6a6;
#             color:  #000000;
#         }#T_cec7c_row2_col6{
#             background-color:  #d29d9d;
#             color:  #000000;
#         }#T_cec7c_row2_col7,#T_cec7c_row14_col5,#T_cec7c_row23_col1{
#             background-color:  #c27474;
#             color:  #000000;
#         }#T_cec7c_row2_col8,#T_cec7c_row10_col5,#T_cec7c_row11_col8,#T_cec7c_row15_col9,#T_cec7c_row29_col8{
#             background-color:  #d39f9f;
#             color:  #000000;
#         }#T_cec7c_row2_col9,#T_cec7c_row14_col9{
#             background-color:  #e5cece;
#             color:  #000000;
#         }#T_cec7c_row3_col4,#T_cec7c_row5_col4,#T_cec7c_row8_col2{
#             background-color:  #f0e9e9;
#             color:  #000000;
#         }#T_cec7c_row3_col5,#T_cec7c_row13_col5,#T_cec7c_row13_col6,#T_cec7c_row22_col5,#T_cec7c_row29_col5{
#             background-color:  #d09999;
#             color:  #000000;
#         }#T_cec7c_row3_col6,#T_cec7c_row6_col8,#T_cec7c_row12_col8,#T_cec7c_row27_col0{
#             background-color:  #cd9191;
#             color:  #000000;
#         }#T_cec7c_row3_col7{
#             background-color:  #b04545;
#             color:  #f1f1f1;
#         }#T_cec7c_row3_col8,#T_cec7c_row15_col5{
#             background-color:  #e1c5c5;
#             color:  #000000;
#         }#T_cec7c_row3_col9,#T_cec7c_row6_col2{
#             background-color:  #eadbdb;
#             color:  #000000;
#         }#T_cec7c_row3_col11,#T_cec7c_row13_col11,#T_cec7c_row17_col11,#T_cec7c_row21_col11,#T_cec7c_row25_col8,#T_cec7c_row25_col11,#T_cec7c_row26_col11{
#             background-color:  #bf6c6c;
#             color:  #000000;
#         }#T_cec7c_row5_col1{
#             background-color:  #c17272;
#             color:  #000000;
#         }#T_cec7c_row5_col3,#T_cec7c_row9_col3,#T_cec7c_row12_col3,#T_cec7c_row13_col3,#T_cec7c_row19_col3,#T_cec7c_row22_col2,#T_cec7c_row24_col3,#T_cec7c_row26_col9{
#             background-color:  #e9d7d7;
#             color:  #000000;
#         }#T_cec7c_row5_col5,#T_cec7c_row24_col5,#T_cec7c_row27_col5{
#             background-color:  #dab2b2;
#             color:  #000000;
#         }#T_cec7c_row5_col6,#T_cec7c_row17_col0,#T_cec7c_row17_col6,#T_cec7c_row28_col1,#T_cec7c_row28_col5{
#             background-color:  #dcb8b8;
#             color:  #000000;
#         }#T_cec7c_row6_col0,#T_cec7c_row13_col0,#T_cec7c_row15_col0{
#             background-color:  #cf9797;
#             color:  #000000;
#         }#T_cec7c_row6_col1,#T_cec7c_row15_col7,#T_cec7c_row23_col7,#T_cec7c_row26_col1,#T_cec7c_row28_col8,#T_cec7c_row29_col2{
#             background-color:  #c98686;
#             color:  #000000;
#         }#T_cec7c_row6_col3,#T_cec7c_row10_col3,#T_cec7c_row11_col3,#T_cec7c_row15_col3,#T_cec7c_row29_col4{

# %%
#an automatic way to get a color map for each quality.
#unfor that method doesn't work in jupyter.

def perQua(x):
    wine[wine.quality == x].head().style.background_gradient(cmap=sns.light_palette("red", as_cmap=True))

minQuality = wine.quality.min()
maxQuality = wine.quality.max()

for x in np.arange(minQuality, maxQuality+1):
    perQua(x)

# %% [markdown]
# ### Correlation heat-table

# %%
def get_headmap(wine: dict):
    corr = wine.corr().abs()
    plt.figure(figsize=(15, 15))
    sns.heatmap(corr, annot=True, cmap="Reds", linewidths=0.1, annot_kws={"fontsize":10})
    plt.title("Correlation whine classification", size=20)
get_headmap(wine)

# %% [markdown]
# ### Counting amount per quality

# %%
#method to calculate how much wines are in any quality

winePerQua = {}
for value in wine.quality:
    if value not in winePerQua:
        winePerQua[value] = 0
    winePerQua[value] += 1
winePerQua
# Out:
# {5: 483, 6: 462, 7: 143, 4: 33, 8: 16, 3: 6}

# %%
#spliting winePerQua to 2 lists - one for values, one for qualities.
values = [vl for vl in winePerQua.values()]
names = [nm for nm in winePerQua]

# %%
plt.figure(figsize=(7, 7))
plt.pie([values][0], radius = 1, shadow=True,
        labels=[names][0], counterclock=False, autopct='%1.1f%%', pctdistance=0.9, explode=[0,0,0,0,0,0.4])
#plt.pie([wine.shape[0]], labeldistance=-0, radius=0.5, colors=['powderblue'])
plt.title("Quality proportion in dataset")
plt.show()

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Spliting to train and test

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
Y = wine['quality']
X = wine[wine.columns[0: len(wine.columns)-1]]

# %%
X.head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8

# %%
Y.head(3)
# Out:
# 0    5
# 1    5
# 2    5
# Name: quality, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=20)
print(f'Training {x_train.shape}')
print(f'Test {x_test.shape}')
# Out:
# Training (914, 11)
# Test (229, 11)

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

print('Train dataset after scaler:')
pd.DataFrame(x_train).head(10).style.background_gradient(cmap=sns.light_palette("brown", as_cmap=True))
# Out:
# Train dataset after scaler:
# <style  type="text/css" >
# #T_dd9e7_row0_col0{
#             background-color:  #d29f9f;
#             color:  #000000;
#         }#T_dd9e7_row0_col1,#T_dd9e7_row1_col6,#T_dd9e7_row1_col8,#T_dd9e7_row2_col5,#T_dd9e7_row4_col3,#T_dd9e7_row4_col9,#T_dd9e7_row4_col10,#T_dd9e7_row6_col0,#T_dd9e7_row6_col2,#T_dd9e7_row6_col7,#T_dd9e7_row7_col4{
#             background-color:  #a52a2a;
#             color:  #f1f1f1;
#         }#T_dd9e7_row0_col2,#T_dd9e7_row0_col10,#T_dd9e7_row1_col0,#T_dd9e7_row2_col0,#T_dd9e7_row2_col4,#T_dd9e7_row2_col7,#T_dd9e7_row2_col9,#T_dd9e7_row3_col10,#T_dd9e7_row4_col5,#T_dd9e7_row4_col6,#T_dd9e7_row5_col5,#T_dd9e7_row6_col8,#T_dd9e7_row8_col10,#T_dd9e7_row9_col1,#T_dd9e7_row9_col3{
#             background-color:  #f2f0f0;
#             color:  #000000;
#         }#T_dd9e7_row0_col3{
#             background-color:  #e0c2c2;
#             color:  #000000;
#         }#T_dd9e7_row0_col4{
#             background-color:  #d09898;
#             color:  #000000;
#         }#T_dd9e7_row0_col5,#T_dd9e7_row1_col5,#T_dd9e7_row6_col3{
#             background-color:  #e3caca;
#             color:  #000000;
#         }#T_dd9e7_row0_col6,#T_dd9e7_row7_col5{
#             background-color:  #dcb7b7;
#             color:  #000000;
#         }#T_dd9e7_row0_col7{
#             background-color:  #ab3a3a;
#             color:  #f1f1f1;
#         }#T_dd9e7_row0_col8,#T_dd9e7_row7_col10{
#             background-color:  #b45050;
#             color:  #f1f1f1;
#         }#T_dd9e7_row0_col9,#T_dd9e7_row1_col4,#T_dd9e7_row3_col4,#T_dd9e7_row3_col9{
#             background-color:  #d5a6a6;
#             color:  #000000;
#         }#T_dd9e7_row1_col1,#T_dd9e7_row7_col9{
#             background-color:  #ac3c3c;
#             color:  #f1f1f1;
#         }#T_dd9e7_row1_col2{
#             background-color:  #dfc0c0;
#             color:  #000000;
#         }#T_dd9e7_row1_col3{
#             background-color:  #ece0e0;
#             color:  #000000;
#         }#T_dd9e7_row1_col7{
#             background-color:  #c98787;
#             color:  #000000;
#         }#T_dd9e7_row1_col9{
#             background-color:  #bb6161;
#             color:  #000000;
#         }#T_dd9e7_row1_col10{
#             background-color:  #cf9797;
#             color:  #000000;
#         }#T_dd9e7_row2_col1{
#             background-color:  #ebdede;
#             color:  #000000;
#         }#T_dd9e7_row2_col2{
#             background-color:  #d8acac;
#             color:  #000000;
#         }#T_dd9e7_row2_col3,#T_dd9e7_row8_col3{
#             background-color:  #e7d3d3;
#             color:  #000000;
#         }#T_dd9e7_row2_col6{
#             background-color:  #b34d4d;
#             color:  #f1f1f1;
#         }#T_dd9e7_row2_col8{
#             background-color:  #c37676;
#             color:  #000000;
#         }#T_dd9e7_row2_col10{
#             background-color:  #bb6363;
#             color:  #000000;
#         }#T_dd9e7_row3_col0{
#             background-color:  #c67f7f;
#             color:  #000000;
#         }#T_dd9e7_row3_col1{
#             background-color:  #b75757;
#             color:  #000000;
#         }#T_dd9e7_row3_col2{
#             background-color:  #e1c4c4;
#             color:  #000000;
#         }#T_dd9e7_row3_col3{
#             background-color:  #efe8e8;
#             color:  #000000;
#         }#T_dd9e7_row3_col5,#T_dd9e7_row9_col6{
#             background-color:  #e8d6d6;
#             color:  #000000;
#         }#T_dd9e7_row3_col6{
#             background-color:  #e5cdcd;
#             color:  #000000;
#         }#T_dd9e7_row3_col7{
#             background-color:  #b85a5a;
#             color:  #000000;
#         }#T_dd9e7_row3_col8{
#             background-color:  #e9dada;
#             color:  #000000;
#         }#T_dd9e7_row4_col0{
#             background-color:  #c27575;
#             color:  #000000;
#         }#T_dd9e7_row4_col1{
#             background-color:  #e4cccc;
#             color:  #000000;
#         }#T_dd9e7_row4_col2{
#             background-color:  #bd6767;
#             color:  #000000;
#         }#T_dd9e7_row4_col4{
#             background-color:  #d9aeae;
#             color:  #000000;
#         }#T_dd9e7_row4_col7,#T_dd9e7_row8_col2,#T_dd9e7_row8_col7{
#             background-color:  #b65656;
#             color:  #000000;
#         }#T_dd9e7_row4_col8,#T_dd9e7_row8_col8{
#             background-color:  #cb8d8d;
#             color:  #000000;
#         }#T_dd9e7_row5_col0,#T_dd9e7_row9_col9{
#             background-color:  #ce9494;
#             color:  #000000;
#         }#T_dd9e7_row5_col1{
#             background-color:  #c57b7b;
#             color:  #000000;
#         }#T_dd9e7_row5_col2{
#             background-color:  #ce9393;
#             color:  #000000;
#         }#T_dd9e7_row5_col3{
#             background-color:  #d3a0a0;
#             color:  #000000;
#         }#T_dd9e7_row5_col4{
#             background-color:  #d5a4a4;
#             color:  #000000;
#         }#T_dd9e7_row5_col6{
#             background-color:  #f2efef;
#             color:  #000000;
#         }#T_dd9e7_row5_col7{
#             background-color:  #ad3d3d;
#             color:  #f1f1f1;
#         }#T_dd9e7_row5_col8{
#             background-color:  #ba5f5f;
#             color:  #000000;
#         }#T_dd9e7_row5_col9{
#             background-color:  #dbb4b4;
#             color:  #000000;
#         }#T_dd9e7_row5_col10{
#             background-color:  #d4a3a3;
#             color:  #000000;
#         }#T_dd9e7_row6_col1{
#             background-color:  #dab1b1;
#             color:  #000000;
#         }#T_dd9e7_row6_col4{
#             background-color:  #d5a5a5;
#             color:  #000000;
#         }#T_dd9e7_row6_col5{
#             background-color:  #b14a4a;
#             color:  #f1f1f1;
#         }#T_dd9e7_row6_col6{
#             background-color:  #c78282;
#             color:  #000000;
#         }#T_dd9e7_row6_col9{
#             background-color:  #b55353;
#             color:  #f1f1f1;
#         }#T_dd9e7_row6_col10{
#             background-color:  #d9b0b0;
#             color:  #000000;
#         }#T_dd9e7_row7_col0{
#             background-color:  #dcb6b6;
#             color:  #000000;
#         }#T_dd9e7_row7_col1{
#             background-color:  #e6d1d1;
#             color:  #000000;
#         }#T_dd9e7_row7_col2,#T_dd9e7_row9_col7{
#             background-color:  #d6a7a7;
#             color:  #000000;
#         }#T_dd9e7_row7_col3{
#             background-color:  #dbb5b5;
#             color:  #000000;
#         }#T_dd9e7_row7_col6{
#             background-color:  #e9d8d8;
#             color:  #000000;
#         }#T_dd9e7_row7_col7{
#             background-color:  #ca8888;
#             color:  #000000;
#         }#T_dd9e7_row7_col8{
#             background-color:  #cf9494;
#             color:  #000000;
#         }#T_dd9e7_row8_col0,#T_dd9e7_row8_col1{
#             background-color:  #d19b9b;
#             color:  #000000;
#         }#T_dd9e7_row8_col4{
#             background-color:  #d39f9f;
#             color:  #000000;
#         }#T_dd9e7_row8_col5,#T_dd9e7_row8_col9,#T_dd9e7_row9_col10{
#             background-color:  #c57d7d;
#             color:  #000000;
#         }#T_dd9e7_row8_col6{
#             background-color:  #a72f2f;
#             color:  #f1f1f1;
#         }#T_dd9e7_row9_col0{
#             background-color:  #d6a9a9;
#             color:  #000000;
#         }#T_dd9e7_row9_col2{
#             background-color:  #cc8f8f;
#             color:  #000000;
#         }#T_dd9e7_row9_col4{
#             background-color:  #e0c2c1;
#             color:  #000000;
#         }#T_dd9e7_row9_col5{
#             background-color:  #debdbd;
#             color:  #000000;
#         }#T_dd9e7_row9_col8{
#             background-color:  #e6d2d2;
#             color:  #000000;
#         }</style><table id="T_dd9e7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>        <th class="col_heading level0 col4" >4</th>        <th class="col_heading level0 col5" >5</th>        <th class="col_heading level0 col6" >6</th>        <th class="col_heading level0 col7" >7</th>        <t

# %% [markdown]
# ### Dummy model

# %%
optQua = len(wine.quality.unique())
dummyModelScore = 1 / optQua
print(f'Score: {dummyModelScore}')
# Out:
# Score: 0.16666666666666666

# %% [markdown]
# ### Xgb model

# %%
import xgboost
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %%
#this takes like 60 secs
parameters = {'n_estimors': np.arange(50, 300, 50), 'max_depth':np.arange(4, 14, 2)}

model_xgb = XGBClassifier(learning_rate=0.3, n_estimators=300, max_depth=14, verbosity = 0)
clf = GridSearchCV(model_xgb, parameters)
print("loading ...")
clf.fit(x_train, y_train)
print("Done!")
# Out:
# loading ...
# Done!

# %%
clf.cv_results_
# Out:
# {'mean_fit_time': array([0.89577971, 0.85655231, 0.87929997, 0.87330418, 0.87792606,
#         0.96032405, 0.91899209, 0.91209545, 0.92160354, 0.9237958 ,
#         0.94450302, 0.929422  , 0.97627406, 1.06207767, 1.0753623 ,
#         1.01039033, 0.94480729, 0.90578489, 0.96302819, 0.97187471,
#         0.93149214, 0.96294627, 0.9412497 , 0.91265593, 0.92368188]),
#  'std_fit_time': array([0.05525509, 0.01272188, 0.02231953, 0.02965756, 0.04253408,
#         0.01326711, 0.02689973, 0.01788238, 0.0379564 , 0.04157135,
#         0.02589796, 0.0528707 , 0.04925623, 0.08663324, 0.08656512,
#         0.08782951, 0.00759724, 0.01910928, 0.03579671, 0.01543824,
#         0.01135658, 0.07435319, 0.03273245, 0.02427823, 0.02879519]),
#  'mean_score_time': array([0.00586991, 0.00725379, 0.00670943, 0.00652852, 0.00706711,
#         0.00701137, 0.00598631, 0.00604157, 0.00673094, 0.00733867,
#         0.00627337, 0.00761571, 0.00738511, 0.00731039, 0.0077457 ,
#         0.00737052, 0.006391  , 0.0077455 , 0.00709138, 0.00716319,
#         0.00667734, 0.00730944, 0.007201  , 0.0083004 , 0.00729604]),
#  'std_score_time': array([0.00156557, 0.00054792, 0.00073647, 0.00106335, 0.00135782,
#         0.00114276, 0.00150608, 0.000677  , 0.00120319, 0.0005986 ,
#         0.00171363, 0.00119701, 0.00155835, 0.0014258 , 0.00120037,
#         0.00076455, 0.00067661, 0.0007175 , 0.00134469, 0.00131044,
#         0.0021803 , 0.00182655, 0.00056412, 0.00074946, 0.00143514]),
#  'param_max_depth': masked_array(data=[4, 4, 4, 4, 4, 6, 6, 6, 6, 6, 8, 8, 8, 8, 8, 10, 10,
#                     10, 10, 10, 12, 12, 12, 12, 12],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimors': masked_array(data=[50, 100, 150, 200, 250, 50, 100, 150, 200, 250, 50,
#                     100, 150, 200, 250, 50, 100, 150, 200, 250, 50, 100,
#                     150, 200, 250],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_depth': 4, 'n_estimors': 50},
#   {'max_depth': 4, 'n_estimors': 100},
#   {'max_depth': 4, 'n_estimors': 150},
#   {'max_depth': 4, 'n_estimors': 200},
#   {'max_depth': 4, 'n_estimors': 250},
#   {'max_depth': 6, 'n_estimors': 50},
#   {'max_depth': 6, 'n_estimors': 100},
#   {'max_depth': 6, 'n_estimors': 150},
#   {'max_depth': 6, 'n_estimors': 200},
#   {'max_depth': 6, 'n_estimors': 250},
#   {'max_depth': 8, 'n_estimors': 50},
#   {'max_depth': 8, 'n_estimors': 100},
#   {'max_depth': 8, 'n_estimors': 150},
#   {'max_depth': 8, 'n_estimors': 200},
#   {'max_depth': 8, 'n_estimors': 250},
#   {'max_depth': 10, 'n_estimors': 50},
#   {'max_depth': 10, 'n_estimors': 100},
#   {'max_depth': 10, 'n_estimors': 150},
#   {'max_depth': 10, 'n_estimors': 200},
#   {'max_depth': 10, 'n_estimors': 250},
#   {'max_depth': 12, 'n_estimors': 50},
#   {'max_depth': 12, 'n_estimors': 100},
#   {'max_depth': 12, 'n_estimors': 150},
#   {'max_depth': 12, 'n_estimors': 200},
#   {'max_depth': 12, 'n_estimors': 250}],
#  'split0_test_score': array([0.6284153 , 0.6284153 , 0.6284153 , 0.6284153 , 0.6284153 ,
#         0.63387978, 0.63387978, 0.63387978, 0.63387978, 0.63387978,
#         0.63934426, 0.63934426, 0.63934426, 0.63934426, 0.63934426,
#         0.63387978, 0.63387978, 0.63387978, 0.63387978, 0.63387978,
#         0.62295082, 0.62295082, 0.62295082, 0.62295082, 0.62295082]),
#  'split1_test_score': array([0.63934426, 0.63934426, 0.63934426, 0.63934426, 0.63934426,
#         0.63387978, 0.63387978, 0.63387978, 0.63387978, 0.63387978,
#         0.61202186, 0.61202186, 0.61202186, 0.61202186, 0.61202186,
#         0.6010929 , 0.6010929 , 0.6010929 , 0.6010929 , 0.6010929 ,
#         0.65027322, 0.65027322, 0.65027322, 0.65027322, 0.65027322]),
#  'split2_test_score': array([0.6010929 , 0.6010929 , 0.6010929 , 0.6010929 , 0.6010929 ,
#         0.59016393, 0.59016393, 0.59016393, 0.59016393, 0.59016393,
#         0.59562842, 0.59562842, 0.59562842, 0.59562842, 0.59562842,
#         0.59562842, 0.59562842, 0.59562842, 0.59562842, 0.59562842,
#         0.60655738, 0.60655738, 0.60655738, 0.60655738, 0.60655738]),
#  'split3_test_score': array([0.6557377 , 0.6557377 , 0.6557377 , 0.6557377 , 0.6557377 ,
#         0.66666667, 0.66666667, 0.66666667, 0.66666667, 0.66666667,
#         0.6557377 , 0.6557377 , 0.6557377 , 0.6557377 , 0.6557377 ,
#         0.63934426, 0.63934426, 0.63934426, 0.63934426, 0.63934426,
#         0.64480874, 0.64480874, 0.64480874, 0.64480874, 0.64480874]),
#  'split4_test_score': array([0.64835165, 0.64835165, 0.64835165, 0.64835165, 0.64835165,
#         0.67032967, 0.67032967, 0.67032967, 0.67032967, 0.67032967,
#         0.67582418, 0.67582418, 0.67582418, 0.67582418, 0.67582418,
#         0.65384615, 0.65384615, 0.65384615, 0.65384615, 0.65384615,
#         0.65384615, 0.65384615, 0.65384615, 0.65384615, 0.65384615]),
#  'mean_test_score': array([0.63458836, 0.63458836, 0.63458836, 0.63458836, 0.63458836,
#         0.63898397, 0.63898397, 0.63898397, 0.63898397, 0.63898397,
#         0.63571128, 0.63571128, 0.63571128, 0.63571128, 0.63571128,
#         0.6247583 , 0.6247583 , 0.6247583 , 0.6247583 , 0.6247583 ,
#         0.63568726, 0.63568726, 0.63568726, 0.63568726, 0.63568726]),
#  'std_test_score': array([0.01907561, 0.01907561, 0.01907561, 0.01907561, 0.01907561,
#         0.02892883, 0.02892883, 0.02892883, 0.02892883, 0.02892883,
#         0.02895212, 0.02895212, 0.02895212, 0.02895212, 0.02895212,
#         0.02258609, 0.02258609, 0.02258609, 0.02258609, 0.02258609,
#         0.01809124, 0.01809124, 0.01809124, 0.01809124, 0.01809124]),
#  'rank_test_score': array([16, 16, 16, 16, 16,  1,  1,  1,  1,  1,  6,  6,  6,  6,  6, 21, 21,
#         21, 21, 21, 11, 11, 11, 11, 11])}

# %%
print(f'Best Score: {clf.best_score_}')
print(f'Best Hyperparameters: {clf.best_params_}')
# Out:
# Best Score: 0.6389839668528193
# Best Hyperparameters: {'max_depth': 6, 'n_estimors': 50}

# %%
print(f'This model is better than the dummy model by {pow(clf.best_score_, 2) / pow(dummyModelScore, 2)} times')
# Out:
# This model is better than the dummy model by 14.698818356218737 times

# %% [markdown]
# # Testing

# %%
Model_xgb = clf.best_estimator_
print(Model_xgb.score(x_test ,y_test))
# Out:
# 0.5720524017467249

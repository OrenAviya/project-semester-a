# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
cast = pd.read_csv(r"C:\Users\avoav\Introduction to Data Science\Project סמסטר א\project-semester-a\Cast.csv"  )
cast.head()
# Out:
#                                title  year       name   type character     n
# 0                    Suuri illusioni  1985     Homo $  actor    Guests  22.0
# 1     Gangsta Rap: The Glockumentary  2007  Too $hort  actor   Himself   NaN
# 2                  Menace II Society  1993  Too $hort  actor   Lew-Loc  27.0
# 3  Porndogs: The Adventures of Sadie  2009  Too $hort  actor     Bosco   3.0
# 4                 Stop Pepper Palmer  2014  Too $hort  actor   Himself   NaN

# %% [markdown]
# 1.	How many movies have the title "Hamlet"?

# %%
hamlet = cast[cast.title == "Hamlet"]
len(hamlet)
# Out:
# 114

# %% [markdown]
#  2.List all of the "Treasure Island" movies from earliest to most recent.

# %%
Treasure_Island = cast[cast.title == "Treasure Island"]
Treasure_Island.sort_values(by = "year", ascending = True)
# Out:
#                   title  year               name   type  \
# 778631  Treasure Island  1918          Joe Grant  actor
# 768752  Treasure Island  1918     Charles Gorman  actor
# 313097  Treasure Island  1918  Francis Carpenter  actor
# 842286  Treasure Island  1918       Edwin Harley  actor
# 648794  Treasure Island  1920       Al W. Filson  actor
# ...                 ...   ...                ...    ...
# 807985  Treasure Island  1999      Paul Gutrecht  actor
# 193382  Treasure Island  1999     Jonah Blechman  actor
# 283873  Treasure Island  1999       Bob Byington  actor
# 411804  Treasure Island  1999        Becket Cook  actor
# 545971  Treasure Island  1999      Jamie Donovan  actor
#
#                       character     n
# 778631  Undetermined child role   NaN
# 768752          Prologue Player   NaN
# 313097              Jim Hawkins   1.0
# 842286          Prologue Player   NaN
# 648794               Bill Bones   3.0
# ...                         ...   ...
# ...

# %% [markdown]
# 3.	How many roles were credited in the silent 1921 version of Hamlet?

# %%
hamlet_1 = hamlet[hamlet.year == 1921]
#print(hamlet_1)
len(hamlet_1)
# Out:
# 4

# %% [markdown]
# 4.	Use groupby() to plot the number of "Hamlet" films made each decade

# %%
hamlet['decade'] = hamlet.year%100%10
h = hamlet[['decade', 'title']].groupby(['decade']).count()
h
# Out:
# <ipython-input-12-c26bcef63d7d>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hamlet['decade'] = hamlet.year%100%10
#         title
# decade
# 0          20
# 1           7
# 3          12
# 4          22
# 5           1
# 6          25
# 8           4
# 9          23

# %%
#just check...
hamlet[hamlet['decade'] == 8]
# Out:
#          title  year              name   type                    character  \
# 91568   Hamlet  1948      Felix Aylmer  actor  Polonius - Lord Chamberlain
# 279308  Hamlet  1948   Anthony Bushell  actor                     Bit Part
# 454826  Hamlet  1948     Peter Cushing  actor                        Osric
# 909296  Hamlet  1948  Stanley Holloway  actor                  Gravedigger
#
#            n  decade
# 91568   15.0       8
# 279308   NaN       8
# 454826   8.0       8
# 909296   9.0       8

# %% [markdown]
# 5.	How many leading (n=1) roles were available to actors, and how many to actresses, in each year of the 1950s?

# %%
ca = cast[(cast.year>= 1950) & (cast.year<=1960)]
ca = ca[ca.n == 1]
len(ca)
# Out:
# 3352

# %% [markdown]
# 6.	List the 10 actors/actresses that have the most leading roles (n=1) since the 1990's.

# %%
actors = cast[cast['year'] >= 1990]
actors = actors[actors['n']== 1.0]
actors.name.value_counts().head(10)
# Out:
# Jayaram               76
# Ajay Devgn            69
# Amitabh Bachchan      68
# Nagarjuna Akkineni    60
# Dilip                 59
# Govinda               58
# Kamal Haasan          56
# Suresh Gopi           54
# Sanjay Dutt           54
# Stephen Chow          52
# Name: name, dtype: int64

# %% [markdown]
# 7.	List, in order by year, each of the films in which Frank Oz has played more than 1 role

# %%
#there is no such name in this data, so I use other name...

c = cast[cast.name=='Francis Carpenter']
c['roles_num'] = c.title.value_counts()[1]
c[c.roles_num > 1].sort_values(by = 'year')
# Out:
# <ipython-input-190-afae8fecaf8e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   c['roles_num'] = c.title.value_counts()[1]
#                                                    title  year  \
# 313085                                    Old Heidelberg  1915
# 313090                            The Commanding Officer  1915
# 313096                                       The Patriot  1916
# 313094                           The Little School Ma'am  1916
# 313089                         The Children in the House  1916
# 313084                              Martha's Vindication  1916
# 313083                                           Macbeth  1916
# 313082                                   Let Katie Do It  1916
# ...
